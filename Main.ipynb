# %% [markdown]
# # **Step#1 Data Collection From FAST-NU Website**

# %% [markdown]
# ## Necessary Libraries

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## FAST School of Computing Faculty Data

# %%
URL = "https://lhr.nu.edu.pk/faculty/#fsc"
page = requests.get(URL)
print(page)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content, "html.parser")
soup.find("div", class_="container", id="fsc")
# Out:
# <div class="container" id="fsc">
# <br>
# <h1 class="mb-2 mt-3">FAST School of Computing Faculty</h1>
# <hr class="mt-0 nu-hr mb-0"/>
# <div class="container tab-pane active" id="faculty-tab"><br/>
# <div class="row">
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/01._Dr_Kashif_Zafar_Prof._CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Kashif Zafar</h5>
# <p class="small text-center font-italic">Professor &amp; HOD
#
#                          <br> HEC Approved PhD Supervisor
#
#                         </br></p>
# <p class="mb-0 text-center">kashif.zafar@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 569</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/1238"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/51._Dr_Aamir_Wali_Prof._AIDS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Aamir Wali</h5>
# <p class="small text-center font-italic">Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">aamir.wali@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 572</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/4027"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/02._Dr_Asif_Mehmood_Gilani_Prof._CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Asif Mahmood Gillani</h5>
# <p class="small text-center font-italic">Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">asif.gilani@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 558</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/4391"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/07._Dr_Asma_Naseer_Assoc._Prof._CS.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Asma Naseer</h5>
# <p class="small text-center font-italic">Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">asma.naseer@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 634</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6113"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/03._Dr_Zareen_Alamgir_Prof._CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Zareen Alamgir</h5>
# <p class="small text-center font-italic">Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">zareen.alamgir@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 612</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/4329"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Dr._Muhammad_Aasim_Qureshi-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Aasim Qureshi</h5>
# <p class="small text-center font-italic">Associate Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">aasim.qureshi@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 558</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6968"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/65._Dr_Ali_Afzal_Malik_Asst._Prof._SE_SM6VFgQ.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Ali Afzal Malik</h5>
# <p class="small text-center font-italic">Associate Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">ali.afzal@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 311</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/9113"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/04._Sr_Arshad_Ali_Assoc._Prof._CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Arshad Ali</h5>
# <p class="small text-center font-italic">Associate Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">arshad.ali1@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 607</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6174"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/52._Dr_Maryam_Bashir_Asst._Prof._AIDS_1jSZW7K.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Maryam Bashir</h5>
# <p class="small text-center font-italic">Associate Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">maryam.bashir@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 635</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/9540"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/05-_Dr_Rana_Asif_Rehman_Assoc._Prof._CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Rana Asif Rehman</h5>
# <p class="small text-center font-italic">Associate Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">r.asif@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 595</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/5181"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/06._Dr_Saira_Karim_Assoc._Prof._CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Saira Karim</h5>
# <p class="small text-center font-italic">Associate Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">saira.karim@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 617</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/4261"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/08._Dr_Zeeshan_Ali_Khan_Assoc._Prof._CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Zeeshan Ali Khan</h5>
# <p class="small text-center font-italic">Associate Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">zeeshanali.khan@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 606</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6048"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/12._Dr_Aatira_Anum_Asst._Prof._CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Aatira Anum</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">aatira.anum@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 586</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/5116"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/13._Dr_Abdul_Qadeer_Asst._Prof._CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Abdul Qadeer</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">aqadeer@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 644</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6811"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/14._Dr_Ahmad_Raza_Asst._Prof._CS_T2lFicM.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Ahmad Raza</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">muhammad.ahmadraza@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 621</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/4236"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/10._Dr_Ammar_Haider_Assist._Prof._CS.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Ammar Haider</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">ammar.haider@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 597</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6418"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/54._Dr_Asma_Ahmad_Asst._Prof._AIDS_RWyt2iB.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Asma Ahmad Farhan</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">asma.ahmad@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 212</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/4335"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/11._Dr_Faisal_Aslam_Asst._Prof._CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Faisal Aslam</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">faisal.aslam@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 614</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6667"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/64._Dr_Farooq_Ahmed_Asst._Prof._SE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Farooq Ahmed</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">farooq.ahmad@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 577</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/4677"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/55._Dr_Hajra_Waheed_Asst._Prof._AIDS_zvotU88.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Hajra Waheed</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">hajra.waheed@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 625</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6562"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/08_-_Dr._Haroon_Mahmood_Asst_Prof_CS__1_-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Haroon Mahmood</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                          <br/> HEC Approved PhD Supervisor
#                          <br/> On Leave
#                         </p>
# <p class="mb-0 text-center">haroon.mahmood@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 237</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/9539"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/13_-_Dr._Iqra_Safdar_Asst_Prof_CS-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Iqra Safder</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#                          <br/> On Leave
#                         </p>
# <p class="mb-0 text-center">iqra.safder@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6273"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/53._Dr_Mirza_Mubasher_Baig_Asst._Prof._AIDS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Mirza Mubasher Baig</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">mubasher.baig@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 591</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/5114"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/6302_5wrK2JS-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Syed Mohammad Irteza</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">m.Irteza@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 247</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6302"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/09._Dr_Tahir_Ejaz_Asst._Prof._CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Tahir Ejaz</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">tahir.ejaz@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 553</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6255"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/66_Dr_Zeeshan_Ali_Rana_Asst._Prof._SE_PatO3hE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Zeeshan Ali Rana</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">zeeshan.rana@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 562</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/5466"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/01_-_Dr._Hammad_Naveed_Professor_CS__Director__1_-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Hammad Naveed</h5>
# <p class="small text-center font-italic">Adj. Professor
#
#                          <br/> HEC Approved PhD Supervisor
#                          <br/> On Leave
#                         </p>
# <p class="mb-0 text-center">hammad.naveed@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 227</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/5424"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/16._Aamir_Raheem_Asst._Prof._CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Aamir Raheem</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">aamir.raheem@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 559</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/3720"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/20._Abeeda_Akram_Asst._Prof._CS.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Abeeda Akram</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">abeeda.akram@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 593</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/5054"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/24._Bushra_Rashid_Asst._Prof._CS.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Bushra Rashid</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">bushra.rashid@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 247</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/4234"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/15._Ishaq_Raza_Asst._Prof._CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Ishaq Raza</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">ishaq.raza@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 214</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/4015"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/21._Lehmia_Kiran_Asst._Prof._CS.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Lehmia Kiran</h5>
# <p class="small text-center font-italic">Assistant Professor
#                          <br/> On Leave
#                         </p>
# <p class="mb-0 text-center">lehmia.kiran@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 604</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/4507"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/23._Maimoona_Akram_Asst._Prof._CS.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Maimoona Akram</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">maimoona.akram@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 247</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/4239"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/22._Mirza_Waqar_Baig_Asst._Prof._CS_hvK0Pyz.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Mirza Waqar Baig</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">waqar.baig@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 414</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/5103"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/028_Noshaba_Nasir_AP_CS-removebg-preview_1-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Noshaba Nasir</h5>
# <p class="small text-center font-italic">Assistant Professor
#                          <br/> On Leave
#                         </p>
# <p class="mb-0 text-center">noshaba.nasir@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 219</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/5221"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/17._Samin_Iftikhar_Asst_Prof._CS.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Samin Iftikhar</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">samin.iftikhar@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 581</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/5115"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/19._Sobia_Tariq_Javed_Asst._Prof._CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Sobia Tariq Javed</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">sobia.tariq@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 641</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/4232"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/18._Waqas_Manzoor_Assit_Prof._CS.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Waqas Manzoor</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">waqas.manzoor@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 618</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/5230"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/30._Aleena_Ahmad_Lecturer_CS.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Aleena Ahmad</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">aleena.ahmad@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 552</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6172"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/71._Anoosha_Khan_Lecturer_SE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Anosha Khan</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">anosha.khan@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 626</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6311"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/62._Ansa_Liaqat_Lecturer_AIDS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Ansa Liaqat</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">ansa.liaqat@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6379"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Aqsa_Khalid-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Aqsa Khalid</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">aqsa.khalid@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 551</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6924"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/70._Arooj_Khalil_Lecturer_SE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Arooj Khalil</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">arooj.khalil@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 633</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6305"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/38._Asbah_Khalid_Lecturer_CS.jpg"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Asbah Khalid</h5>
# <p class="small text-center font-italic">Lecturer
#                          <br/> On Leave
#                         </p>
# <p class="mb-0 text-center">asbah.khalid@lhr.nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 360</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6723"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/34._Danyal_Farhat_Lecturer_CS_oDWYVFu.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Danyal Farhat</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">danyal.farhat@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 642</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6553"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/61._Eesha_Tur_Raziz_Baber_Lecturer_AIDS.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Eesha Tur Razia Babar</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">esha.razia@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 556</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6788"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/72._Fraz_Yousaf_Lecturer_SE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Fraz Yousaf</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">fraz.yousaf@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 598</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6274"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/26._Usama_Hassan_Alvi_Lecturer_CS.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Hafiz Usama Hassan Alvi</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">usama.hassan@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 582</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6308"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/59._Hamad_Ul_Qudous_Lecturer_AIDS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Hamad Ul Qudous</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">hamad.ulqudous@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 620</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6307"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/73._Hina_Iqbal_Lecturer_SE.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Hina Iqbal</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">hina.iqbal@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 560</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6551"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/36._Hira_Butt_Lecturer_CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Hira Butt</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">hira.butt@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 580</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6419"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/40._Kiran_Khurshid_Lecturer_CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Kiran Khurshid</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">kiran.khurshid@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 594</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6820"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/56._M_Saif_Ul_Islam_Lecturer_AIDS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. M. Saif Ul Islam</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">muhammad.saif@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 603</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6588"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/35._Maham_Naeem_Lecturer_CS.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Maham Naeem</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">maham.naeem@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 615</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6277"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/42._Mamoona_Akbar_Jun._Lect._CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Mamoona Akbar Khan</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">mamoona.akbar@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 587</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6253"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/74._Mamoona_Majid_Lecturer_SE.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Mamoona Majid</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">mamoona.majid@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 602</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6549"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/75._Mehroze_Khan_Lecturer_SE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Mehroze Khan</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">mehroze.khan@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 629</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6560"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/69._Momna_Zaneb_Lecturer_SE.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Momna Zaneb</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">momna.zaneb@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 590</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6295"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/31._Mubashar_Hussain_Lecturer_CS.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Mubashar Hussain</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">mubashar.hussain@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 638</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6415"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/29._Muhammad_Naveed_Lecturer_CS_la7oUg9.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Muhammad Naveed</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">muhammad.naveed@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 554</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6114"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/33._Namra_Absar_Lecturer_CS.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Namra Absar</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">namra.absar@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 557</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6554"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/68._Razi_Uddin_Lectrurer_SE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Razi-uddin</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">razi.uddin@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 592</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/5967"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/32._Rubab_Anam_Janjua_Lecturer_CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Rubab Anam Janjua</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">rubab.anam@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 637</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6552"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/28._Saifullah_Tanvir_Lecturer_CS.jpeg"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Saifullah Tanvir</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">saifullah.tanvir@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 575</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6268"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/39._Sajid_Ali_Kazmi_Lecturer_CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Sajid Ali Kazmi</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">sajid.kazmi@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 600</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6773"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/41._Salman_Shoaib_jun._Lect_CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Salman Shoaib</h5>
# <p class="small text-center font-italic">Lecturer
#                          <br/> On Leave
#                         </p>
# <p class="mb-0 text-center">salman.shoaib@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 570</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/5986"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/57._Sana_Fatima_Lecturer_AIDS.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Sana Fatima</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">sana.fatima@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 589</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6171"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/48._Seemab_Ayub_Instructor_CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Seemab Ayub</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">seemab.ayub@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 627</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6719"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Syed_Ayaz_Gillani-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Syed Ayaz Gillani</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">ayaz.gillani@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6925"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/27._Syed_Uzair_Hussain_Lecturer_CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Syed Uzair Hussain Naqvi</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">uzair.naqvi@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 304</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6309"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/60._Umm_e_Ammarah_Lecturer_AIDS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Umm E Ammarah</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">umme.ammarah@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 631</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6559"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/47._Usman_Anwar_Instructor_CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Usman Anwer</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">usman.anwer@lhr.nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 630</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6722"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Waqas_Ali-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Waqas Ali</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">rana.waqasali@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 600</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6927"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/37._Zeeshan_Nazar_Lecturer_CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Zeeshan Nazar</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">zeeshan.nazar@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 588</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6662"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Amina_Qaiser-removebg-preview_fJER9uf.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Amina Qaiser</h5>
# <p class="small text-center font-italic">Instructor
#
#                         </p>
# <p class="mb-0 text-center">amina.qaiser@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 599</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6928"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/63._Aqib_Zeeshan_Instructor_AIDS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Aqib Zeeshan</h5>
# <p class="small text-center font-italic">Instructor
#
#                         </p>
# <p class="mb-0 text-center">aqib.zeeshan@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 611</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6791"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/50._Hashir_Mohsineen_Instructor_CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Hashir Mohsineen</h5>
# <p class="small text-center font-italic">Instructor
#
#                         </p>
# <p class="mb-0 text-center">hashir.mhsineen@lhr.nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 630</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6838"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/46._Junaid_Hussain_Muzamal_Instructor_CS.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Junaid Hussain Muzammal</h5>
# <p class="small text-center font-italic">Instructor
#
#                         </p>
# <p class="mb-0 text-center">junaid.hussain@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 906</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6422"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Maria_Hassan-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Maria Hassan</h5>
# <p class="small text-center font-italic">Instructor
#
#                         </p>
# <p class="mb-0 text-center">maria.hassan@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 632</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6929"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/76._Muhammad_Hasan_Instructor_SE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Muhammad Hasan</h5>
# <p class="small text-center font-italic">Instructor
#
#                         </p>
# <p class="mb-0 text-center">m.hasan@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 611</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6767"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/49._Sukhan_Amir_Instructor_CS_ax2daD0.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Sukhan Amir</h5>
# <p class="small text-center font-italic">Instructor
#
#                         </p>
# <p class="mb-0 text-center">sukhan.amir@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 627</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6718"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/6568.jpg"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Syeda Zehra Batool</h5>
# <p class="small text-center font-italic">Instructor
#                          <br/> On Leave
#                         </p>
# <p class="mb-0 text-center">zehra.batool@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 525</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6568"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/45._Zoha_Waheed_Instructor_CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Zoha Waheed</h5>
# <p class="small text-center font-italic">Instructor
#
#                         </p>
# <p class="mb-0 text-center">zoha.waheed@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 632</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6663"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Zulqarnain-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Zulqarnain</h5>
# <p class="small text-center font-italic">Instructor
#
#                         </p>
# <p class="mb-0 text-center">zulqarnain.Ishaq@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6943"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/67._Amir_Iqbal_Adj._Faculty_SE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Amir Iqbal</h5>
# <p class="small text-center font-italic">Adj. Faculty
#
#                         </p>
# <p class="mb-0 text-center">amir.iqbal@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6772"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/44._Marwa_Khan_Jun._Lect._CS.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Marwa Khan</h5>
# <p class="small text-center font-italic">Junior Lecturer
#
#                         </p>
# <p class="mb-0 text-center">marwa.khan@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 610</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6770"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/25._Nauman_Moazzam_Hayat_Adj_Faculty_CS.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Nauman Moazzam Hayat</h5>
# <p class="small text-center font-italic">Adj. Faculty
#
#                         </p>
# <p class="mb-0 text-center">nauman.moazzam@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 619</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6176"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/43._Saba_Tariq_Junior_Lecturer_CS.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Saba Tariq</h5>
# <p class="small text-center font-italic">Junior Lecturer
#
#                         </p>
# <p class="mb-0 text-center">saba.tariq@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 610</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6771"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/39-_Samman_Ashraf_Jun._Lect._CS-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Samman Ashraf</h5>
# <p class="small text-center font-italic">Junior Lecturer
#                          <br/> On Leave
#                         </p>
# <p class="mb-0 text-center">samman.ashraf@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/fsc/facultyProfile/6558"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </br></div>

# %%
divs = soup.find(class_="container", id="fsc").find_all(
    class_="col-lg-3 col-md-4 col-sm-6 col-12"
)

# %% [markdown]
# ## Data Frame Preparation

# %%
joint_data = pd.DataFrame()

data_list = []

for div in divs:
    faculty_link = div.find("a", class_="faculty-link")
    href = faculty_link["href"] if faculty_link else None

    new_data = {
        "ID": href.split("/")[-1] if href else None,
        "Name": (
            div.find("h5", class_="text-center").text.strip()
            if div.find("h5", class_="text-center")
            else None
        ),
        "Designation": (
            div.find("p", class_="small text-center font-italic")
            .get_text(separator=" ", strip=True)
            .split("HEC Approved")[0]
            .strip()
            if div.find("p", class_="small text-center font-italic")
            else None
        ),
        "HEC Approved PHD Supervisor": (
            "HEC Approved"
            in div.find("p", class_="small text-center font-italic").get_text(
                separator=" ", strip=True
            )
            if div.find("p", class_="small text-center font-italic")
            else False
        ),
        "Email": (
            div.find("p", class_="mb-0 text-center").text.strip()
            if div.find("p", class_="mb-0 text-center")
            else None
        ),
        "Department": href.split("/")[1] if href else None,
        "ImageURL": (
            div.find(
                "img", class_="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto"
            ).get("src")
            if div.find(
                "img", class_="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto"
            )
            else None
        ),
    }

    data_list.append(new_data)

joint_data = pd.DataFrame(data_list)
joint_data.head()
# Out:
#      ID                      Name      Designation  \
# 0  1238          Dr. Kashif Zafar  Professor & HOD
# 1  4027            Dr. Aamir Wali        Professor
# 2  4391  Dr. Asif Mahmood Gillani        Professor
# 3  6113           Dr. Asma Naseer        Professor
# 4  4329        Dr. Zareen Alamgir        Professor
#
#    HEC Approved PHD Supervisor                     Email Department  \
# 0                         True    kashif.zafar@nu.edu.pk        fsc
# 1                         True      aamir.wali@nu.edu.pk        fsc
# 2                         True     asif.gilani@nu.edu.pk        fsc
# 3                         True     asma.naseer@nu.edu.pk        fsc
# 4                         True  zareen.alamgir@nu.edu.pk        fsc
#
#                                             ImageURL
# 0    /media/Faculty/01._Dr_Kashif_Zafar_Prof._CS.JPG
# 1    /media/Faculty/51._Dr_Aamir_Wali_Prof._AIDS.JPG
# 2  /media/Faculty/02._Dr_Asif_Mehmood_Gilani_Prof...
# 3  /media/Faculty/07._Dr_Asma_Naseer_Assoc._Prof....
# 4  /media/Faculty/03._Dr_Zareen_Alamgir_Prof._CS.JPG

# %% [markdown]
# ## Data import to .csv file

# %%
joint_data.to_csv("fsc.csv")

# %% [markdown]
# ## Department of Electrical Engineering Faculty Data

# %%
URL = "https://lhr.nu.edu.pk/faculty/#ee"
page = requests.get(URL)
print(page)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content, "html.parser")
soup.find("div", class_="container", id="ee")
# Out:
# <div class="container" id="ee">
# <br/>
# <h1 class="mb-2 mt-3">Department of Electrical Engineering Faculty</h1>
# <hr class="mt-0 nu-hr mb-0"/>
# <div class="container tab-pane active" id="faculty-tab"><br/>
# <div class="row">
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/98._Dr_Saima_Zafar_Prof._EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Saima Zafar</h5>
# <p class="small text-center font-italic">Professor &amp; HOD
#
#                          <br> HEC Approved PhD Supervisor
#
#                         </br></p>
# <p class="mb-0 text-center">saima.zafar@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 265</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/4198"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/99._Dr_S_M_Sajid_Prof._EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. S.M. Sajid</h5>
# <p class="small text-center font-italic">Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">sm.sajid@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 315</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/4108"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/100._Dr_Syed_Aun_Abbas_Prof._EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Syed Aun Abbas</h5>
# <p class="small text-center font-italic">Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">aun.abbas@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 254</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/5421"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/101._Dr_Omer_Saleem_Associate_Professor_EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Omer Saleem</h5>
# <p class="small text-center font-italic">Associate Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">omer.saleem@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 364</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/4609"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Dr._Huzaifa_Rauf-removebg-preview_1.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Huzaifa Rauf</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">huzaifa.rauf@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 235</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/6942"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/102._Dr_Kashif_Saeed_Asst._Prof._EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Kashif Saeed</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">kashif.saeed@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 244</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/9452"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/104._Abdul_Majid_Asst._Prof._EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Abdul Majid</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">abdul.majid@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 146</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/4023"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/108._Beenish_Fatima_Asst._Prof._EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Beenish Fatima</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">beenish.fatima@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 314</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/4233"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/109._Syed_Haris_Mujtaba_Asst._Prof._EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Haris Mujtaba</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">haris.kazmi@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 421</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/3669"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/106._Mohsin_Yousaf_Asst._Prof._EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Mohsin Yousaf</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">mohsin.yousuf@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 317</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/3461"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/105._Shazia_Haque_Asst._Prof._EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Shazia Haque</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">shazia.haque@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 269</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/4484"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/107._Tamania_Javaid_Asst._Prof._EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Tamania Javed</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">tamania.javaid@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 309</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/3778"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Abeer_Bashir-removebg-preview_1.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Abeer Bashir</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">abeer.bashir@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 237</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/7025"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/116._Ahmad_Hamza_Nayyar_Lecturer_EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Ahmad Hamza Nayyar</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">ahmad.hamza@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/6289"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/110._Akbare_Yaqub_Lecturer_EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Akbare Yaqub</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">akbari.yaqoob@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 309</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/3779"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/112._Aroosa_Umair_Lecturer_EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Aroosa Umair</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">aroosa.umair@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 286</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/5218"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/111._Sara_Kiran_Lecturer_EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Sara Kiran</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">sara.kiran@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 276</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/4809"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/118._Syed_Maaz_Ahmed_Rizvi_Lecturer_EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Syed Maaz Ahmed Rizvi</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">maaz.ahmed@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/6843"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/113._Syed_M._Ismail_Lecturer_EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Syed Muhammad Ismail</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">muhammad.ismail@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 287</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/5231"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/115._Umer_Altaf_Lecturer_EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Umer Altaf</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">umer.altaf@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 287</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/6557"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Aliha_Tanveer-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Aliha Tanveer</h5>
# <p class="small text-center font-italic">Lab Engineer
#
#                         </p>
# <p class="mb-0 text-center">aliha.tanveer@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/7005"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/119._Eisha_Khan_Lab._Engineer_EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Eisha Khan</h5>
# <p class="small text-center font-italic">Lab Engineer
#
#                         </p>
# <p class="mb-0 text-center">eisha.khan@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/6665"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/120._Hafiz_M._Muiz_Malik_Lab._Engineer_EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Hafiz Muhammad Muiz Malik</h5>
# <p class="small text-center font-italic">Lab Engineer
#
#                         </p>
# <p class="mb-0 text-center">muiz.malik@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/6830"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Syeda_Sughra_Kamran-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Syeda Sughra Kamran</h5>
# <p class="small text-center font-italic">Lab Engineer
#
#                         </p>
# <p class="mb-0 text-center">sughra.kamran@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/7002"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>

# %%
divs = soup.find(class_="container", id="ee").find_all(
    class_="col-lg-3 col-md-4 col-sm-6 col-12"
)
print(divs)
# Out:
# [<div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/98._Dr_Saima_Zafar_Prof._EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Saima Zafar</h5>
# <p class="small text-center font-italic">Professor &amp; HOD
#
#                          <br> HEC Approved PhD Supervisor
#
#                         </br></p>
# <p class="mb-0 text-center">saima.zafar@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 265</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/4198"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/99._Dr_S_M_Sajid_Prof._EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. S.M. Sajid</h5>
# <p class="small text-center font-italic">Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">sm.sajid@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 315</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/4108"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/100._Dr_Syed_Aun_Abbas_Prof._EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Syed Aun Abbas</h5>
# <p class="small text-center font-italic">Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">aun.abbas@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 254</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/5421"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/101._Dr_Omer_Saleem_Associate_Professor_EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Omer Saleem</h5>
# <p class="small text-center font-italic">Associate Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">omer.saleem@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 364</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/4609"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Dr._Huzaifa_Rauf-removebg-preview_1.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Huzaifa Rauf</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">huzaifa.rauf@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 235</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/6942"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/102._Dr_Kashif_Saeed_Asst._Prof._EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Kashif Saeed</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">kashif.saeed@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 244</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/9452"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/104._Abdul_Majid_Asst._Prof._EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Abdul Majid</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">abdul.majid@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 146</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/4023"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/108._Beenish_Fatima_Asst._Prof._EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Beenish Fatima</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">beenish.fatima@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 314</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/4233"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/109._Syed_Haris_Mujtaba_Asst._Prof._EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Haris Mujtaba</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">haris.kazmi@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 421</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/3669"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/106._Mohsin_Yousaf_Asst._Prof._EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Mohsin Yousaf</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">mohsin.yousuf@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 317</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/3461"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/105._Shazia_Haque_Asst._Prof._EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Shazia Haque</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">shazia.haque@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 269</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/4484"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/107._Tamania_Javaid_Asst._Prof._EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Tamania Javed</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">tamania.javaid@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 309</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/3778"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Abeer_Bashir-removebg-preview_1.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Abeer Bashir</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">abeer.bashir@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 237</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/7025"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/116._Ahmad_Hamza_Nayyar_Lecturer_EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Ahmad Hamza Nayyar</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">ahmad.hamza@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/6289"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/110._Akbare_Yaqub_Lecturer_EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Akbare Yaqub</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">akbari.yaqoob@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 309</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/3779"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/112._Aroosa_Umair_Lecturer_EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Aroosa Umair</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">aroosa.umair@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 286</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/5218"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/111._Sara_Kiran_Lecturer_EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Sara Kiran</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">sara.kiran@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 276</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/4809"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/118._Syed_Maaz_Ahmed_Rizvi_Lecturer_EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Syed Maaz Ahmed Rizvi</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">maaz.ahmed@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/6843"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/113._Syed_M._Ismail_Lecturer_EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Syed Muhammad Ismail</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">muhammad.ismail@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 287</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/5231"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/115._Umer_Altaf_Lecturer_EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Umer Altaf</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">umer.altaf@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 287</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/6557"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Aliha_Tanveer-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Aliha Tanveer</h5>
# <p class="small text-center font-italic">Lab Engineer
#
#                         </p>
# <p class="mb-0 text-center">aliha.tanveer@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/7005"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/119._Eisha_Khan_Lab._Engineer_EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Eisha Khan</h5>
# <p class="small text-center font-italic">Lab Engineer
#
#                         </p>
# <p class="mb-0 text-center">eisha.khan@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/6665"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/120._Hafiz_M._Muiz_Malik_Lab._Engineer_EE.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Hafiz Muhammad Muiz Malik</h5>
# <p class="small text-center font-italic">Lab Engineer
#
#                         </p>
# <p class="mb-0 text-center">muiz.malik@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/6830"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Syeda_Sughra_Kamran-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Syeda Sughra Kamran</h5>
# <p class="small text-center font-italic">Lab Engineer
#
#                         </p>
# <p class="mb-0 text-center">sughra.kamran@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/ee/facultyProfile/7002"></a>
# </div>
# </div>
# </div>]

# %% [markdown]
# ## Data Frame Preparation

# %%
joint_data = pd.DataFrame()

data_list = []

for div in divs:
    faculty_link = div.find("a", class_="faculty-link")
    href = faculty_link["href"] if faculty_link else None

    new_data = {
        "ID": href.split("/")[-1] if href else None,
        "Name": (
            div.find("h5", class_="text-center").text.strip()
            if div.find("h5", class_="text-center")
            else None
        ),
        "Designation": (
            div.find("p", class_="small text-center font-italic")
            .get_text(separator=" ", strip=True)
            .split("HEC Approved")[0]
            .strip()
            if div.find("p", class_="small text-center font-italic")
            else None
        ),
        "HEC Approved PHD Supervisor": (
            "HEC Approved"
            in div.find("p", class_="small text-center font-italic").get_text(
                separator=" ", strip=True
            )
            if div.find("p", class_="small text-center font-italic")
            else False
        ),
        "Email": (
            div.find("p", class_="mb-0 text-center").text.strip()
            if div.find("p", class_="mb-0 text-center")
            else None
        ),
        "Department": href.split("/")[1] if href else None,
        "ImageURL": (
            div.find(
                "img", class_="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto"
            ).get("src")
            if div.find(
                "img", class_="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto"
            )
            else None
        ),
    }

    data_list.append(new_data)

joint_data = pd.DataFrame(data_list)
joint_data.head()
# Out:
#      ID                Name          Designation  HEC Approved PHD Supervisor  \
# 0  4198     Dr. Saima Zafar      Professor & HOD                         True
# 1  4108      Dr. S.M. Sajid            Professor                         True
# 2  5421  Dr. Syed Aun Abbas            Professor                        False
# 3  4609     Dr. Omer Saleem  Associate Professor                         True
# 4  6942    Dr. Huzaifa Rauf  Assistant Professor                        False
#
#                     Email Department  \
# 0   saima.zafar@nu.edu.pk         ee
# 1      sm.sajid@nu.edu.pk         ee
# 2     aun.abbas@nu.edu.pk         ee
# 3   omer.saleem@nu.edu.pk         ee
# 4  huzaifa.rauf@nu.edu.pk         ee
#
#                                             ImageURL
# 0     /media/Faculty/98._Dr_Saima_Zafar_Prof._EE.JPG
# 1       /media/Faculty/99._Dr_S_M_Sajid_Prof._EE.JPG
# 2  /media/Faculty/100._Dr_Syed_Aun_Abbas_Prof._EE...
# 3  /media/Faculty/101._Dr_Omer_Saleem_Associate_P...
# 4  /media/Faculty/Dr._Huzaifa_Rauf-removebg-previ...

# %% [markdown]
# ## Data import to .csv file

# %%
joint_data.to_csv("ee.csv")

# %% [markdown]
# ## Department of Civil Engineering

# %%
URL = "https://lhr.nu.edu.pk/faculty/#cv"
page = requests.get(URL)
print(page)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content, "html.parser")
soup.find("div", class_="container", id="cv")
# Out:
# <div class="container" id="cv">
# <br/>
# <h1 class="mb-2 mt-3">Department of Civil Engineering Faculty</h1>
# <hr class="mt-0 nu-hr mb-0"/>
# <div class="container tab-pane active" id="faculty-tab"><br/>
# <div class="row">
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/77._Dr_Tauqir_Ahmed_Prof._CvL.jpg"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Tauqir Ahmed</h5>
# <p class="small text-center font-italic">Associate Professor &amp; HOD
#
#                          <br> HEC Approved PhD Supervisor
#
#                         </br></p>
# <p class="mb-0 text-center">tauqir.ahmed@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 417</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/5818"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/78._Dr_Shahid_Ali_Prof._CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Shahid Ali</h5>
# <p class="small text-center font-italic">Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">shahid.ali@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 339</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/9451"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/79._Dr_Syed_Ali_Rizwan_Prof._CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Syed Ali Rizwan Bukhari</h5>
# <p class="small text-center font-italic">Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">syed.ali@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 228</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/5705"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Dr._Muhammad_Azam-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Muhammad Azam</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">muhammad.azam@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 414</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/6941"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/80._Dr_Muhammad_Umar_Asst._Prof._CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Muhammad Umar</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">m.umar@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 450</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/6047"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/83._Ali_Raza_Khalid_Asst._Prof._CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Ali Raza Khalid</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">aliraza.khalid@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 433</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/9513"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/81._Sarah_Asif_Asst._Prof._CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Sarah Asif</h5>
# <p class="small text-center font-italic">Assistant Professor
#                          <br/> On Leave
#                         </p>
# <p class="mb-0 text-center">sarah.asif@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 452</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/4592"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/82._Umar_Khan_Niazi_Asst._Prof._CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Umar Khan Niazi</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">umar.niazi@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 218</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/5360"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/87._Anns_Tahir_Lecturer_CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Anns Tahir</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">anns.tahir@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 426</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/6041"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/86._Asim_Iqbal_Lecturer_CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Asim Iqbal</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">asim.iqbal@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 448</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/4300"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/90._Asim_Sharif_Lecturer_CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Asim Sharif</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">asim.sharif@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 446</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/6839"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/85._Fahad_Haseeb_Lecturer_CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Fahad Haseeb</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">fahad.haseeb@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 330</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/5553"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/88._Mah_Noor_Lecturer_CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Mahnoor Akram</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">mahnoor.akram@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 236</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/6573"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/89._Muhammad_Bilal_Zahid_Lecturer_CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Muhammad Bilal Zahid</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">bilal.zahid@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 459</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/6817"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Sania_Khalid-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Sania Khalid</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">sania.khalid@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 433</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/7026"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/97._Abdur_Rehman_Zahid_Lab._Engineer_CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Abdur Rehman Zahid</h5>
# <p class="small text-center font-italic">Lab Engineer
#
#                         </p>
# <p class="mb-0 text-center">abdur.rehman@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/6818"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/96._Abu_Huraira_Lab._Engineer_CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Abu Huraira</h5>
# <p class="small text-center font-italic">Lab Engineer
#
#                         </p>
# <p class="mb-0 text-center">abu.huraira@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/6816"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/91._Hamza_Ali_Lab_Engineer_CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Hamza Ali</h5>
# <p class="small text-center font-italic">Lab Engineer
#
#                         </p>
# <p class="mb-0 text-center">hamza.ali@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/6569"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Kashif_Hameed-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Kashif Hameed</h5>
# <p class="small text-center font-italic">Lab Engineer
#
#                         </p>
# <p class="mb-0 text-center">kashif.hameed@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 447</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/6934"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/95._Umer_Amin_Khan_Lab_EnginerCvL.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. M. Umer Amin Khan</h5>
# <p class="small text-center font-italic">Lab Engineer
#
#                         </p>
# <p class="mb-0 text-center">umer.amin@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/6769"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/94._Maham_Akram_Lab_Engineer_CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Maham Akram</h5>
# <p class="small text-center font-italic">Lab Engineer
#
#                         </p>
# <p class="mb-0 text-center">maham.akram@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/6571"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Muhammad_Zaid_Bin_Shahid-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Zaid Bin Shahid</h5>
# <p class="small text-center font-italic">Lab Engineer
#
#                         </p>
# <p class="mb-0 text-center">muhammad.zaid@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 422</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/6933"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>

# %%
divs = soup.find(class_="container", id="cv").find_all(
    class_="col-lg-3 col-md-4 col-sm-6 col-12"
)
print(divs)
# Out:
# [<div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/77._Dr_Tauqir_Ahmed_Prof._CvL.jpg"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Tauqir Ahmed</h5>
# <p class="small text-center font-italic">Associate Professor &amp; HOD
#
#                          <br> HEC Approved PhD Supervisor
#
#                         </br></p>
# <p class="mb-0 text-center">tauqir.ahmed@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 417</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/5818"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/78._Dr_Shahid_Ali_Prof._CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Shahid Ali</h5>
# <p class="small text-center font-italic">Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">shahid.ali@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 339</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/9451"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/79._Dr_Syed_Ali_Rizwan_Prof._CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Syed Ali Rizwan Bukhari</h5>
# <p class="small text-center font-italic">Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">syed.ali@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 228</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/5705"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Dr._Muhammad_Azam-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Muhammad Azam</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">muhammad.azam@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 414</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/6941"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/80._Dr_Muhammad_Umar_Asst._Prof._CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Muhammad Umar</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">m.umar@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 450</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/6047"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/83._Ali_Raza_Khalid_Asst._Prof._CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Ali Raza Khalid</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">aliraza.khalid@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 433</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/9513"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/81._Sarah_Asif_Asst._Prof._CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Sarah Asif</h5>
# <p class="small text-center font-italic">Assistant Professor
#                          <br/> On Leave
#                         </p>
# <p class="mb-0 text-center">sarah.asif@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 452</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/4592"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/82._Umar_Khan_Niazi_Asst._Prof._CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Umar Khan Niazi</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">umar.niazi@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 218</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/5360"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/87._Anns_Tahir_Lecturer_CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Anns Tahir</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">anns.tahir@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 426</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/6041"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/86._Asim_Iqbal_Lecturer_CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Asim Iqbal</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">asim.iqbal@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 448</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/4300"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/90._Asim_Sharif_Lecturer_CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Asim Sharif</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">asim.sharif@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 446</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/6839"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/85._Fahad_Haseeb_Lecturer_CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Fahad Haseeb</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">fahad.haseeb@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 330</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/5553"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/88._Mah_Noor_Lecturer_CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Mahnoor Akram</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">mahnoor.akram@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 236</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/6573"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/89._Muhammad_Bilal_Zahid_Lecturer_CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Muhammad Bilal Zahid</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">bilal.zahid@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 459</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/6817"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Sania_Khalid-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Sania Khalid</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">sania.khalid@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 433</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/7026"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/97._Abdur_Rehman_Zahid_Lab._Engineer_CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Abdur Rehman Zahid</h5>
# <p class="small text-center font-italic">Lab Engineer
#
#                         </p>
# <p class="mb-0 text-center">abdur.rehman@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/6818"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/96._Abu_Huraira_Lab._Engineer_CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Abu Huraira</h5>
# <p class="small text-center font-italic">Lab Engineer
#
#                         </p>
# <p class="mb-0 text-center">abu.huraira@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/6816"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/91._Hamza_Ali_Lab_Engineer_CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Hamza Ali</h5>
# <p class="small text-center font-italic">Lab Engineer
#
#                         </p>
# <p class="mb-0 text-center">hamza.ali@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/6569"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Kashif_Hameed-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Kashif Hameed</h5>
# <p class="small text-center font-italic">Lab Engineer
#
#                         </p>
# <p class="mb-0 text-center">kashif.hameed@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 447</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/6934"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/95._Umer_Amin_Khan_Lab_EnginerCvL.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. M. Umer Amin Khan</h5>
# <p class="small text-center font-italic">Lab Engineer
#
#                         </p>
# <p class="mb-0 text-center">umer.amin@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/6769"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/94._Maham_Akram_Lab_Engineer_CvL.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Maham Akram</h5>
# <p class="small text-center font-italic">Lab Engineer
#
#                         </p>
# <p class="mb-0 text-center">maham.akram@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/6571"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Muhammad_Zaid_Bin_Shahid-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Zaid Bin Shahid</h5>
# <p class="small text-center font-italic">Lab Engineer
#
#                         </p>
# <p class="mb-0 text-center">muhammad.zaid@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 422</p> -->
# <a class="faculty-link" href="/cv/facultyProfile/6933"></a>
# </div>
# </div>
# </div>]

# %% [markdown]
# ## Data Frame Preparation

# %%
joint_data = pd.DataFrame()

data_list = []

for div in divs:
    faculty_link = div.find("a", class_="faculty-link")
    href = faculty_link["href"] if faculty_link else None

    new_data = {
        "ID": href.split("/")[-1] if href else None,
        "Name": (
            div.find("h5", class_="text-center").text.strip()
            if div.find("h5", class_="text-center")
            else None
        ),
        "Designation": (
            div.find("p", class_="small text-center font-italic")
            .get_text(separator=" ", strip=True)
            .split("HEC Approved")[0]
            .strip()
            if div.find("p", class_="small text-center font-italic")
            else None
        ),
        "HEC Approved PHD Supervisor": (
            "HEC Approved"
            in div.find("p", class_="small text-center font-italic").get_text(
                separator=" ", strip=True
            )
            if div.find("p", class_="small text-center font-italic")
            else False
        ),
        "Email": (
            div.find("p", class_="mb-0 text-center").text.strip()
            if div.find("p", class_="mb-0 text-center")
            else None
        ),
        "Department": href.split("/")[1] if href else None,
        "ImageURL": (
            div.find(
                "img", class_="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto"
            ).get("src")
            if div.find(
                "img", class_="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto"
            )
            else None
        ),
    }

    data_list.append(new_data)

joint_data = pd.DataFrame(data_list)
joint_data.head()
# Out:
#      ID                         Name                Designation  \
# 0  5818             Dr. Tauqir Ahmed  Associate Professor & HOD
# 1  9451               Dr. Shahid Ali                  Professor
# 2  5705  Dr. Syed Ali Rizwan Bukhari                  Professor
# 3  6941            Dr. Muhammad Azam        Assistant Professor
# 4  6047            Dr. Muhammad Umar        Assistant Professor
#
#    HEC Approved PHD Supervisor                    Email Department  \
# 0                         True   tauqir.ahmed@nu.edu.pk         cv
# 1                         True     shahid.ali@nu.edu.pk         cv
# 2                         True       syed.ali@nu.edu.pk         cv
# 3                        False  muhammad.azam@nu.edu.pk         cv
# 4                         True         m.umar@nu.edu.pk         cv
#
#                                             ImageURL
# 0   /media/Faculty/77._Dr_Tauqir_Ahmed_Prof._CvL.jpg
# 1     /media/Faculty/78._Dr_Shahid_Ali_Prof._CvL.JPG
# 2  /media/Faculty/79._Dr_Syed_Ali_Rizwan_Prof._Cv...
# 3  /media/Faculty/Dr._Muhammad_Azam-removebg-prev...
# 4  /media/Faculty/80._Dr_Muhammad_Umar_Asst._Prof...

# %% [markdown]
# ## Data import to .csv file

# %%
joint_data.to_csv("cv.csv")

# %% [markdown]
# ## Fast School of Management

# %%
URL = "https://lhr.nu.edu.pk/faculty/#fsm"
page = requests.get(URL)
print(page)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content, "html.parser")
soup.find("div", class_="container", id="fsm")
# Out:
# <div class="container" id="fsm">
# <br/>
# <h1 class="mb-2 mt-3">FAST School of Management Faculty</h1>
# <hr class="mt-0 nu-hr mb-0"/>
# <div class="container tab-pane active" id="faculty-tab"><br/>
# <div class="row">
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/121._Dr_Hamid_Hassan_Prof_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Hamid Hassan</h5>
# <p class="small text-center font-italic">Professor &amp; HOD
#
#                          <br> HEC Approved PhD Supervisor
#
#                         </br></p>
# <p class="mb-0 text-center">hamid.hassan@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 252</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/3924"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/122.Dr_Akbar_Azam_Assoc._Prof._MG.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Akbar Azam</h5>
# <p class="small text-center font-italic">Associate Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">akbar.azam@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 343</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/4685"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/126._Amna_Farrukh_Assit_Prof._MG.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Amna Farrukh</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#                          <br/> On Leave
#                         </p>
# <p class="mb-0 text-center">amna.farrukh@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 405</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6563"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/128._Dr_Mujahid_Hussain_Asst._Prof._MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Brig Mujahid Hussain</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">mujahid.hussain@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 255</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/5712"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/125._Dr_Fatima_Omer_Asst._Prof._MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Fatima Omer</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">fatima.omer@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 295</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/4629"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/127._Dr_Komal_Kamran_Asst._Prof._MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Komal Kamran</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">komal.kamran@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 316</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6561"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/123._Dr_Mian_M._Atif_Asst._Prof._MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Mian Muhammad Atif</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">mian.atif @nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 408</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/5423"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/129._Dr_Munazza_Saeed_Asst._Prof._MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Munazza Saeed</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">munazza.saeed@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 445</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/5559"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/5427-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Saif Maqbool</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">saif.maqbool@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 250</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/5427"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/120_-_Dr._Umer_Iqbal_Asst_Prof_MG_nr59AV5-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Umer Iqbal</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                          <br/> HEC Approved PhD Supervisor
#                          <br/> On Leave
#                         </p>
# <p class="mb-0 text-center">umer.iqbal@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 242</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6426"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/124._Dr_Zia_Ullah_Khan_Asst._Prof._MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Zia Khan</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">zia.khan@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 409</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/9495"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/130._Aamer_Allauddin_Asst._Prof._MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Aamer Allauddin</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">allauddin@gmail.com</p>
# <!--  <p class="mt-0 small text-center">ext no: 360</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/4483"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/131._Shakeel_Ahmad_Asst._Prof._MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Shakeel Ahmad</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">shakeel.ahmad@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 258</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/4647"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/135._Aroosa_Safdar_Lecturer_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Aroosa Safdar</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">aroosa.safdar@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 325</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/5517"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/133._Beenish_Arshad_Lecturer_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Beenish Arshad</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">beenish.arshad@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 444</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/5227"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Bilal_Qaisar-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Bilal Qaisar</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">bilal.qaisar@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 354</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6930"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/132._Fatima_Habib_Lecturer_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Fatima Habib</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">fatima.habib@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 349</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/5518"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/144._Ghulam_Fatima_Instructor_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Ghulam Fatima</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">ghulam.fatima@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 301</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6115"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/145._Iman_Ilyas_Instructor_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Iman Ilyas</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">iman.ilyas@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 256</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6709"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/138._Irma_Tariq_Lecturer_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Irma Tariq</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">irma.tariq@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 306</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6565"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/139._Khadija_Aslam_Lecturer_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Khadija Aslam</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">khadija.aslam@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 256</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6664"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/140._M_Mubeen_Ajmal_Lecturer_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Muhammad Mobeen Ajmal</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">mobeen.ajmal@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 354</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6812"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/137._Noor_Zahid_Lecture_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Noor Zahid</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">noor.zahid@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 306</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6566"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/142._Salman_Khalil_Rehman_Adj_Fcaulty_MG.jpg"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Salmaan Khalil Rahman</h5>
# <p class="small text-center font-italic">Adjunct Lecturer
#
#                         </p>
# <p class="mb-0 text-center">salmaan.rahman@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/5713"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/141._Sidra_Salman_Lecturer_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Sidra Salman</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">sidra.salman@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 324</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6813"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/134._Sundas_Munir_Lecturer_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Sundas Munir</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">sundas.munir@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 324</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6303"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Zunaira_Ahmed-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Zunaira Ahmed</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">zunaira.ahmed@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 353</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6931"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Alishba_Nisar-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Alishba Nisar</h5>
# <p class="small text-center font-italic">Instructor
#
#                         </p>
# <p class="mb-0 text-center">alishba.nisar@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/7016"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Attiqa_Sohail-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Attiqa Sohail</h5>
# <p class="small text-center font-italic">Instructor
#
#                         </p>
# <p class="mb-0 text-center">attiqa.sohail@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/7017"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/147._Fatima_Zeb_Instructor_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Fatima Zeb</h5>
# <p class="small text-center font-italic">Instructor
#
#                         </p>
# <p class="mb-0 text-center">fatima.zeb@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 301</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6789"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Sadia_Manzoor-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Sadia Manzoor</h5>
# <p class="small text-center font-italic">Instructor
#
#                         </p>
# <p class="mb-0 text-center">sadia.manzoor@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/7015"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Syeda_Fatima_Jaffery-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Syeda Fatima Jaffery</h5>
# <p class="small text-center font-italic">Instructor
#
#                         </p>
# <p class="mb-0 text-center">fatima.jaffery@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 451</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6964"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/146._Syeda_Fatima_Naqvi_Instructor_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Syeda Fatima Naqvi</h5>
# <p class="small text-center font-italic">Instructor
#
#                         </p>
# <p class="mb-0 text-center">fatima.naqvi@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 431</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6790"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/6815__1_-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Aiza Aftab</h5>
# <p class="small text-center font-italic">Junior Lecturer
#
#                         </p>
# <p class="mb-0 text-center">aiza.aftab@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 431</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6815"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Saleena_Gul-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Saleena Gul</h5>
# <p class="small text-center font-italic">Faculty (Adjunct)
#
#                         </p>
# <p class="mb-0 text-center">saleena@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 353</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6932"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>

# %%
divs = soup.find(class_="container", id="fsm").find_all(
    class_="col-lg-3 col-md-4 col-sm-6 col-12"
)
print(divs)
# Out:
# [<div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/121._Dr_Hamid_Hassan_Prof_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Hamid Hassan</h5>
# <p class="small text-center font-italic">Professor &amp; HOD
#
#                          <br> HEC Approved PhD Supervisor
#
#                         </br></p>
# <p class="mb-0 text-center">hamid.hassan@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 252</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/3924"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/122.Dr_Akbar_Azam_Assoc._Prof._MG.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Akbar Azam</h5>
# <p class="small text-center font-italic">Associate Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">akbar.azam@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 343</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/4685"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/126._Amna_Farrukh_Assit_Prof._MG.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Amna Farrukh</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#                          <br/> On Leave
#                         </p>
# <p class="mb-0 text-center">amna.farrukh@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 405</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6563"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/128._Dr_Mujahid_Hussain_Asst._Prof._MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Brig Mujahid Hussain</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">mujahid.hussain@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 255</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/5712"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/125._Dr_Fatima_Omer_Asst._Prof._MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Fatima Omer</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">fatima.omer@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 295</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/4629"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/127._Dr_Komal_Kamran_Asst._Prof._MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Komal Kamran</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">komal.kamran@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 316</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6561"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/123._Dr_Mian_M._Atif_Asst._Prof._MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Mian Muhammad Atif</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">mian.atif @nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 408</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/5423"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/129._Dr_Munazza_Saeed_Asst._Prof._MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Munazza Saeed</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">munazza.saeed@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 445</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/5559"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/5427-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Saif Maqbool</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">saif.maqbool@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 250</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/5427"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/120_-_Dr._Umer_Iqbal_Asst_Prof_MG_nr59AV5-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Umer Iqbal</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                          <br/> HEC Approved PhD Supervisor
#                          <br/> On Leave
#                         </p>
# <p class="mb-0 text-center">umer.iqbal@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 242</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6426"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/124._Dr_Zia_Ullah_Khan_Asst._Prof._MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Zia Khan</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">zia.khan@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 409</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/9495"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/130._Aamer_Allauddin_Asst._Prof._MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Aamer Allauddin</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">allauddin@gmail.com</p>
# <!--  <p class="mt-0 small text-center">ext no: 360</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/4483"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/131._Shakeel_Ahmad_Asst._Prof._MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Shakeel Ahmad</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">shakeel.ahmad@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 258</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/4647"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/135._Aroosa_Safdar_Lecturer_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Aroosa Safdar</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">aroosa.safdar@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 325</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/5517"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/133._Beenish_Arshad_Lecturer_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Beenish Arshad</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">beenish.arshad@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 444</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/5227"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Bilal_Qaisar-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Bilal Qaisar</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">bilal.qaisar@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 354</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6930"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/132._Fatima_Habib_Lecturer_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Fatima Habib</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">fatima.habib@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 349</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/5518"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/144._Ghulam_Fatima_Instructor_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Ghulam Fatima</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">ghulam.fatima@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 301</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6115"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/145._Iman_Ilyas_Instructor_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Iman Ilyas</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">iman.ilyas@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 256</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6709"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/138._Irma_Tariq_Lecturer_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Irma Tariq</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">irma.tariq@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 306</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6565"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/139._Khadija_Aslam_Lecturer_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Khadija Aslam</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">khadija.aslam@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 256</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6664"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/140._M_Mubeen_Ajmal_Lecturer_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Muhammad Mobeen Ajmal</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">mobeen.ajmal@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 354</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6812"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/137._Noor_Zahid_Lecture_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Noor Zahid</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">noor.zahid@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 306</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6566"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/142._Salman_Khalil_Rehman_Adj_Fcaulty_MG.jpg"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Salmaan Khalil Rahman</h5>
# <p class="small text-center font-italic">Adjunct Lecturer
#
#                         </p>
# <p class="mb-0 text-center">salmaan.rahman@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/5713"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/141._Sidra_Salman_Lecturer_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Sidra Salman</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">sidra.salman@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 324</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6813"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/134._Sundas_Munir_Lecturer_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Sundas Munir</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">sundas.munir@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 324</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6303"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Zunaira_Ahmed-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Zunaira Ahmed</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">zunaira.ahmed@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 353</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6931"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Alishba_Nisar-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Alishba Nisar</h5>
# <p class="small text-center font-italic">Instructor
#
#                         </p>
# <p class="mb-0 text-center">alishba.nisar@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/7016"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Attiqa_Sohail-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Attiqa Sohail</h5>
# <p class="small text-center font-italic">Instructor
#
#                         </p>
# <p class="mb-0 text-center">attiqa.sohail@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/7017"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/147._Fatima_Zeb_Instructor_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Fatima Zeb</h5>
# <p class="small text-center font-italic">Instructor
#
#                         </p>
# <p class="mb-0 text-center">fatima.zeb@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 301</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6789"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Sadia_Manzoor-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Sadia Manzoor</h5>
# <p class="small text-center font-italic">Instructor
#
#                         </p>
# <p class="mb-0 text-center">sadia.manzoor@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/7015"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Syeda_Fatima_Jaffery-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Syeda Fatima Jaffery</h5>
# <p class="small text-center font-italic">Instructor
#
#                         </p>
# <p class="mb-0 text-center">fatima.jaffery@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 451</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6964"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/146._Syeda_Fatima_Naqvi_Instructor_MG.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Syeda Fatima Naqvi</h5>
# <p class="small text-center font-italic">Instructor
#
#                         </p>
# <p class="mb-0 text-center">fatima.naqvi@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 431</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6790"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/6815__1_-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Aiza Aftab</h5>
# <p class="small text-center font-italic">Junior Lecturer
#
#                         </p>
# <p class="mb-0 text-center">aiza.aftab@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 431</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6815"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Saleena_Gul-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Saleena Gul</h5>
# <p class="small text-center font-italic">Faculty (Adjunct)
#
#                         </p>
# <p class="mb-0 text-center">saleena@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 353</p> -->
# <a class="faculty-link" href="/fsm/facultyProfile/6932"></a>
# </div>
# </div>
# </div>]

# %% [markdown]
# ## Data Frame Preparation

# %%
joint_data = pd.DataFrame()

data_list = []

for div in divs:
    faculty_link = div.find("a", class_="faculty-link")
    href = faculty_link["href"] if faculty_link else None

    new_data = {
        "ID": href.split("/")[-1] if href else None,
        "Name": (
            div.find("h5", class_="text-center").text.strip()
            if div.find("h5", class_="text-center")
            else None
        ),
        "Designation": (
            div.find("p", class_="small text-center font-italic")
            .get_text(separator=" ", strip=True)
            .split("HEC Approved")[0]
            .strip()
            if div.find("p", class_="small text-center font-italic")
            else None
        ),
        "HEC Approved PHD Supervisor": (
            "HEC Approved"
            in div.find("p", class_="small text-center font-italic").get_text(
                separator=" ", strip=True
            )
            if div.find("p", class_="small text-center font-italic")
            else False
        ),
        "Email": (
            div.find("p", class_="mb-0 text-center").text.strip()
            if div.find("p", class_="mb-0 text-center")
            else None
        ),
        "Department": href.split("/")[1] if href else None,
        "ImageURL": (
            div.find(
                "img", class_="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto"
            ).get("src")
            if div.find(
                "img", class_="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto"
            )
            else None
        ),
    }

    data_list.append(new_data)

joint_data = pd.DataFrame(data_list)
joint_data.head()
# Out:
#      ID                      Name                   Designation  \
# 0  3924          Dr. Hamid Hassan               Professor & HOD
# 1  4685            Dr. Akbar Azam           Associate Professor
# 2  6563          Dr. Amna Farrukh  Assistant Professor On Leave
# 3  5712  Dr. Brig Mujahid Hussain           Assistant Professor
# 4  4629           Dr. Fatima Omer           Assistant Professor
#
#    HEC Approved PHD Supervisor                      Email Department  \
# 0                         True     hamid.hassan@nu.edu.pk        fsm
# 1                         True       akbar.azam@nu.edu.pk        fsm
# 2                        False     amna.farrukh@nu.edu.pk        fsm
# 3                         True  mujahid.hussain@nu.edu.pk        fsm
# 4                        False      fatima.omer@nu.edu.pk        fsm
#
#                                             ImageURL
# 0    /media/Faculty/121._Dr_Hamid_Hassan_Prof_MG.JPG
# 1  /media/Faculty/122.Dr_Akbar_Azam_Assoc._Prof._...
# 2  /media/Faculty/126._Amna_Farrukh_Assit_Prof._M...
# 3  /media/Faculty/128._Dr_Mujahid_Hussain_Asst._P...
# 4  /media/Faculty/125._Dr_Fatima_Omer_Asst._Prof....

# %% [markdown]
# ## Data import to .csv file

# %%
joint_data.to_csv("fsm.csv")

# %% [markdown]
# ## Department of Science and Humanities

# %%
URL = "https://lhr.nu.edu.pk/faculty/#ss"
page = requests.get(URL)
print(page)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content, "html.parser")
soup.find("div", class_="container", id="ss")
# Out:
# <div class="container" id="ss">
# <br/>
# <h1 class="mb-2 mt-3">Department of Science &amp; Humanities Faculty</h1>
# <hr class="mt-0 nu-hr mb-0"/>
# <div class="container tab-pane active" id="faculty-tab"><br/>
# <div class="row">
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/149._Dr_Mubashir_Qayyum_Prof._SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Mubashir Qayyum</h5>
# <p class="small text-center font-italic">Professor &amp; HOD
#
#                          <br> HEC Approved PhD Supervisor
#
#                         </br></p>
# <p class="mb-0 text-center">mubashir.qayyum@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 283</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/4332"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/150._Dr._Akhlaq_Ahmad_Bhatti_Prof._SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Akhlaq Ahmad Bhatti</h5>
# <p class="small text-center font-italic">Professor
#                          <br/> Dean (Faculty of Sciences &amp; Humanities)
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">akhlaq.ahmad@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 284</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/4020"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/151._Dr_Mazhar_Hussain_Prof._SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Mazhar Hussain</h5>
# <p class="small text-center font-italic">Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">mazhar.hussain@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 313</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/3712"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/152._Dr._Saman_Shahid_Prof._SH.jpg"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Saman Shahid</h5>
# <p class="small text-center font-italic">Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">saman.shahid@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 206</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/4250"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/148._Dr_Summaira_Sarfraz_Prof._SH.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Summaira Sarfraz</h5>
# <p class="small text-center font-italic">Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">sumaira.sarfraz@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 227</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/4018"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/137_-_Dr._Farasat_Shamir_Assoc._Prof_Math__HoD_SH-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Farasat Shamir</h5>
# <p class="small text-center font-italic">Associate Professor
#
#                          <br/> HEC Approved PhD Supervisor
#                          <br/> On Leave
#                         </p>
# <p class="mb-0 text-center">farasat.shamir@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 317</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/4584"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/153._Dr_Saeeda_Zia_Assoc._Prof._SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Saeeda Zia</h5>
# <p class="small text-center font-italic">Associate Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">saeeda.zia@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 223</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/1250"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/159._Dr_Hina_Firdous_Asst._Prof._SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Hina Firdous</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">hina.firdous@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 340</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/4608"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/156._Dr_Hira_Iqbal_Asst._Prof._SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Hira Iqbal</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">hira.iqbal@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 363</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/9172"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/158._Dr_Iram_Amjad_Asst._Prof._SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Iram Amjad</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">iram.amjad@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 518</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/6768"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/157._Dr_Tahir_Rashid_Asst._Prof._SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Muhammad Tahir Rashid</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">tahir.rashid@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 442</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/5437"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Dr._Sara_Khan__1_-removebg-preview_1.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Sara Khan</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">sara.khan1@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 526</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/6926"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/155._Dr_Tayyaba_Naz_Asst._Prof._SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Tayyaba Naz</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">tayyaba.naz@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 226</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/9173"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/154._Dr_Zahida_Mansoor_Asst._Prof._SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Zahida Mansoor</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">zahida.mansoor@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 412</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/4243"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/161._Hajra_Ikram_Butt_Asst._Prof._SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Hajira Ikram Butt</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">hajra.ikram@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 432</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/4244"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/160._Zulfiqar_Ali_Asst._Prof._SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Zulfiqar Ali</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">ali.zulfiqar@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 310</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/4245"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/165._Abdul_Sattar_Lecturer_SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Abdul Sattar</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">abdul.sattar@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 249</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/5438"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/164_-_Aisha_Bano_Lecturer_SH-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Aisha Bano</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">aisha.bano@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/5622"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/171_Aqsa_Naz_Lecturer_SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Aqsa Naz</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">aqsa.naz@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 236</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/6555"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/164._Ayesha_Saeed_Lecturer_SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Ayesha Saeed</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">ayesha.saeed@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 526</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/5203"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/162._Hafiz_M._Hamza_Janjua_Lecturer_SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Hafiz Hamza Janjua</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">hamza.janjua@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 524</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/4397"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/170._Kanwal_Saleem_Lecturer_SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Kanwal Saleem</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">kanwal.saleem@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 525</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/6421"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/169._Muhammad_Yaseen_Lecturer_SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Muhammad Yaseen</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">m.yaseen@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 465</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/6365"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/167._Namra_Fazal_Lecturer_SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Namra Fazal</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">namra.fazal@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 456</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/6178"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/174._Nokhaiz_Zahra_Lecturer_SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Nokhaiz Zahra</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">nokhaiz.zahra@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 456</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/6420"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/166._Razm-ul-Zafar_Lecturer_SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Razm-ul-Zafar</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">razm.zafar@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 527</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/5795"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/172._Rubab_Arshad_Lecturer_SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Rubab Arshad</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">rubab.arshad@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 236</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/6548"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/163._Sarah_Ahmad_Lecturer_SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Sarah Ahmad</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">Sarah.ahmad@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 525</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/5337"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/168._Tasaduque_Hussain_Shah_Lecturer_SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Tasaduque Hussain Shah</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">tasduque.hussain@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 524</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/6363"></a>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/175._Mahnoor_Chaudhry_Instructor_SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Mahnoor Chaudhry</h5>
# <p class="small text-center font-italic">Lecturer (English)
#
#                         </p>
# <p class="mb-0 text-center">mahnoor.chaudhary@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/6567"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>

# %%
divs = soup.find(class_="container", id="ss").find_all(
    class_="col-lg-3 col-md-4 col-sm-6 col-12"
)
print(divs)
# Out:
# [<div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/149._Dr_Mubashir_Qayyum_Prof._SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Mubashir Qayyum</h5>
# <p class="small text-center font-italic">Professor &amp; HOD
#
#                          <br> HEC Approved PhD Supervisor
#
#                         </br></p>
# <p class="mb-0 text-center">mubashir.qayyum@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 283</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/4332"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/150._Dr._Akhlaq_Ahmad_Bhatti_Prof._SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Akhlaq Ahmad Bhatti</h5>
# <p class="small text-center font-italic">Professor
#                          <br/> Dean (Faculty of Sciences &amp; Humanities)
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">akhlaq.ahmad@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 284</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/4020"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/151._Dr_Mazhar_Hussain_Prof._SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Mazhar Hussain</h5>
# <p class="small text-center font-italic">Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">mazhar.hussain@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 313</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/3712"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/152._Dr._Saman_Shahid_Prof._SH.jpg"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Saman Shahid</h5>
# <p class="small text-center font-italic">Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">saman.shahid@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 206</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/4250"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/148._Dr_Summaira_Sarfraz_Prof._SH.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Summaira Sarfraz</h5>
# <p class="small text-center font-italic">Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">sumaira.sarfraz@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 227</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/4018"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/137_-_Dr._Farasat_Shamir_Assoc._Prof_Math__HoD_SH-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Farasat Shamir</h5>
# <p class="small text-center font-italic">Associate Professor
#
#                          <br/> HEC Approved PhD Supervisor
#                          <br/> On Leave
#                         </p>
# <p class="mb-0 text-center">farasat.shamir@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 317</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/4584"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/153._Dr_Saeeda_Zia_Assoc._Prof._SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Saeeda Zia</h5>
# <p class="small text-center font-italic">Associate Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">saeeda.zia@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 223</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/1250"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/159._Dr_Hina_Firdous_Asst._Prof._SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Hina Firdous</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">hina.firdous@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 340</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/4608"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/156._Dr_Hira_Iqbal_Asst._Prof._SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Hira Iqbal</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">hira.iqbal@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 363</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/9172"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/158._Dr_Iram_Amjad_Asst._Prof._SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Iram Amjad</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">iram.amjad@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 518</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/6768"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/157._Dr_Tahir_Rashid_Asst._Prof._SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Muhammad Tahir Rashid</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">tahir.rashid@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 442</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/5437"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/Dr._Sara_Khan__1_-removebg-preview_1.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Sara Khan</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#
#
#                         </p>
# <p class="mb-0 text-center">sara.khan1@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 526</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/6926"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/155._Dr_Tayyaba_Naz_Asst._Prof._SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Tayyaba Naz</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">tayyaba.naz@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 226</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/9173"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0 pb-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/154._Dr_Zahida_Mansoor_Asst._Prof._SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Dr. Zahida Mansoor</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                          <br/> HEC Approved PhD Supervisor
#
#                         </p>
# <p class="mb-0 text-center">zahida.mansoor@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 412</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/4243"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/161._Hajra_Ikram_Butt_Asst._Prof._SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Hajira Ikram Butt</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">hajra.ikram@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 432</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/4244"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/160._Zulfiqar_Ali_Asst._Prof._SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Zulfiqar Ali</h5>
# <p class="small text-center font-italic">Assistant Professor
#
#                         </p>
# <p class="mb-0 text-center">ali.zulfiqar@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 310</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/4245"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/165._Abdul_Sattar_Lecturer_SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Abdul Sattar</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">abdul.sattar@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 249</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/5438"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/164_-_Aisha_Bano_Lecturer_SH-removebg-preview.png"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Aisha Bano</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">aisha.bano@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/5622"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/171_Aqsa_Naz_Lecturer_SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Aqsa Naz</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">aqsa.naz@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 236</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/6555"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/164._Ayesha_Saeed_Lecturer_SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Ayesha Saeed</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">ayesha.saeed@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 526</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/5203"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/162._Hafiz_M._Hamza_Janjua_Lecturer_SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Hafiz Hamza Janjua</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">hamza.janjua@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 524</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/4397"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/170._Kanwal_Saleem_Lecturer_SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Kanwal Saleem</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">kanwal.saleem@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 525</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/6421"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/169._Muhammad_Yaseen_Lecturer_SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Muhammad Yaseen</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">m.yaseen@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 465</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/6365"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/167._Namra_Fazal_Lecturer_SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Namra Fazal</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">namra.fazal@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 456</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/6178"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/174._Nokhaiz_Zahra_Lecturer_SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Nokhaiz Zahra</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">nokhaiz.zahra@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 456</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/6420"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/166._Razm-ul-Zafar_Lecturer_SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Razm-ul-Zafar</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">razm.zafar@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 527</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/5795"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/172._Rubab_Arshad_Lecturer_SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Rubab Arshad</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">rubab.arshad@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 236</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/6548"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/163._Sarah_Ahmad_Lecturer_SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Sarah Ahmad</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">Sarah.ahmad@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 525</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/5337"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/168._Tasaduque_Hussain_Shah_Lecturer_SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Mr. Tasaduque Hussain Shah</h5>
# <p class="small text-center font-italic">Lecturer
#
#                         </p>
# <p class="mb-0 text-center">tasduque.hussain@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: 524</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/6363"></a>
# </div>
# </div>
# </div>, <div class="col-lg-3 col-md-4 col-sm-6 col-12">
# <div class="card facultyCard card-br-0 ml-0 mr-0">
# <div class="facultyImage">
# <img class="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto" src="/media/Faculty/175._Mahnoor_Chaudhry_Instructor_SH.JPG"/>
# </div>
# <div class="card-body pr-0 pl-0 pb-0">
# <h5 class="text-center">Ms. Mahnoor Chaudhry</h5>
# <p class="small text-center font-italic">Lecturer (English)
#
#                         </p>
# <p class="mb-0 text-center">mahnoor.chaudhary@nu.edu.pk</p>
# <!--  <p class="mt-0 small text-center">ext no: None</p> -->
# <a class="faculty-link" href="/ss/facultyProfile/6567"></a>
# </div>
# </div>
# </div>]

# %% [markdown]
# ## Data Frame Preparation

# %%
joint_data = pd.DataFrame()

data_list = []

for div in divs:
    faculty_link = div.find("a", class_="faculty-link")
    href = faculty_link["href"] if faculty_link else None

    new_data = {
        "ID": href.split("/")[-1] if href else None,
        "Name": (
            div.find("h5", class_="text-center").text.strip()
            if div.find("h5", class_="text-center")
            else None
        ),
        "Designation": (
            div.find("p", class_="small text-center font-italic")
            .get_text(separator=" ", strip=True)
            .split("HEC Approved")[0]
            .strip()
            if div.find("p", class_="small text-center font-italic")
            else None
        ),
        "HEC Approved PHD Supervisor": (
            "HEC Approved"
            in div.find("p", class_="small text-center font-italic").get_text(
                separator=" ", strip=True
            )
            if div.find("p", class_="small text-center font-italic")
            else False
        ),
        "Email": (
            div.find("p", class_="mb-0 text-center").text.strip()
            if div.find("p", class_="mb-0 text-center")
            else None
        ),
        "Department": href.split("/")[1] if href else None,
        "ImageURL": (
            div.find(
                "img", class_="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto"
            ).get("src")
            if div.find(
                "img", class_="card-img-top rounded-circle mt-3 mb-0 d-block mx-auto"
            )
            else None
        ),
    }

    data_list.append(new_data)

joint_data = pd.DataFrame(data_list)
joint_data.head()
# Out:
#      ID                     Name  \
# 0  4332      Dr. Mubashir Qayyum
# 1  4020  Dr. Akhlaq Ahmad Bhatti
# 2  3712       Dr. Mazhar Hussain
# 3  4250         Dr. Saman Shahid
# 4  4018     Dr. Summaira Sarfraz
#
#                                          Designation  \
# 0                                    Professor & HOD
# 1  Professor Dean (Faculty of Sciences & Humanities)
# 2                                          Professor
# 3                                          Professor
# 4                                          Professor
#
#    HEC Approved PHD Supervisor                      Email Department  \
# 0                         True  mubashir.qayyum@nu.edu.pk         ss
# 1                         True     akhlaq.ahmad@nu.edu.pk         ss
# 2                         True   mazhar.hussain@nu.edu.pk         ss
# 3                         True     saman.shahid@nu.edu.pk         ss
# 4                         True  sumaira.sarfraz@nu.edu.pk         ss
#
#                                             ImageURL
# 0  /media/Faculty/149._Dr_Mubashir_Qayyum_Prof._S...
# 1  /media/Faculty/150._Dr._Akhlaq_Ahmad_Bhatti_Pr...
# 2  /media/Faculty/151._Dr_Mazhar_Hussain_Prof._SH...
# 3  /media/Faculty/152._Dr._Saman_Shahid_Prof._SH.jpg
# 4  /media/Faculty/148._Dr_Summaira_Sarfraz_Prof._...

# %% [markdown]
# ## Data import to .csv file

# %%
joint_data.to_csv("ss.csv")

# %% [markdown]
# # **Step#2 Iterator & Data Frame Creation**

# %% [markdown]
# ## FAST School of Computing Faculty Data

# %%
fsc_file = pd.read_csv("fsc.csv")
fsc_new_data_frame = pd.DataFrame(fsc_file)
fsc_new_data_frame.head()
# Out:
#    Unnamed: 0    ID                      Name      Designation  \
# 0           0  1238          Dr. Kashif Zafar  Professor & HOD
# 1           1  4027            Dr. Aamir Wali        Professor
# 2           2  4391  Dr. Asif Mahmood Gillani        Professor
# 3           3  6113           Dr. Asma Naseer        Professor
# 4           4  4329        Dr. Zareen Alamgir        Professor
#
#    HEC Approved PHD Supervisor                     Email Department  \
# 0                         True    kashif.zafar@nu.edu.pk        fsc
# 1                         True      aamir.wali@nu.edu.pk        fsc
# 2                         True     asif.gilani@nu.edu.pk        fsc
# 3                         True     asma.naseer@nu.edu.pk        fsc
# 4                         True  zareen.alamgir@nu.edu.pk        fsc
#
#                                             ImageURL
# 0    /media/Faculty/01._Dr_Kashif_Zafar_Prof._CS.JPG
# 1    /media/Faculty/51._Dr_Aamir_Wali_Prof._AIDS.JPG
# 2  /media/Faculty/02._Dr_Asif_Mehmood_Gilani_Prof...
# 3  /media/Faculty/07._Dr_Asma_Naseer_Assoc._Prof....
# 4  /media/Faculty/03._Dr_Zareen_Alamgir_Prof._CS.JPG

# %%
ID_List = fsc_new_data_frame["ID"].tolist()
print(ID_List)

ID_data_frame = pd.DataFrame(columns=["ID", "Extension", "Highest Education"])
ID_data_frame.head()
# Out:
# [1238, 4027, 4391, 6113, 4329, 6968, 9113, 6174, 9540, 5181, 4261, 6048, 5116, 6811, 4236, 6418, 4335, 6667, 4677, 6562, 9539, 6273, 5114, 6302, 6255, 5466, 5424, 3720, 5054, 4234, 4015, 4507, 4239, 5103, 5221, 5115, 4232, 5230, 6172, 6311, 6379, 6924, 6305, 6723, 6553, 6788, 6274, 6308, 6307, 6551, 6419, 6820, 6588, 6277, 6253, 6549, 6560, 6295, 6415, 6114, 6554, 5967, 6552, 6268, 6773, 5986, 6171, 6719, 6925, 6309, 6559, 6722, 6927, 6662, 6928, 6791, 6838, 6422, 6929, 6767, 6718, 6568, 6663, 6943, 6772, 6770, 6176, 6771, 6558]
# Empty DataFrame
# Columns: [ID, Extension, Highest Education]
# Index: []

# %% [markdown]
# ## New data Frame

# %%
data_list = []

for ID in ID_List:
    URL = f"http://lhr.nu.edu.pk/fsc/facultyProfile/{ID}"
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, "html.parser")

    # Extracting Extension
    extension = "N/A"
    phone_ext = soup.find("span", class_="small")
    if phone_ext and "Ext:" in phone_ext.text:
        extension = phone_ext.text.split("Ext:")[1].strip()

    # Extracting Education (highest degree)
    latest_education = "N/A"
    education_section = soup.find(
        "div", class_="col-lg-8 col-md-6 col-sm-12 text-justify"
    )
    if education_section:
        ul_tag = education_section.find("ul")
        if ul_tag:
            li_tags = ul_tag.find_all("li")
            if li_tags:
                latest_education = li_tags[0].text.strip()

    new_data = {"ID": ID, "Extension": extension, "Highest Education": latest_education}

    data_list.append(new_data)

# %%
ID_data_frame = pd.DataFrame(data_list)
ID_data_frame.head()
# Out:
#      ID Extension                                  Highest Education
# 0  1238       569                  PhD (CS), NUCES, Islamabad (2010)
# 1  4027       572                     PhD (CS), NUCES, Lahore (2019)
# 2  4391       558  Ph.D(Computing), University of Patras , Greece...
# 3  6113       634                     PhD (CS), NUCES, Lahore (2018)
# 4  4329       612                    Ph.D (CS), NUCES, Lahore (2014)

# %% [markdown]
# ## Import to .csv file

# %%
ID_data_frame.to_csv("fsc_2.csv")

# %% [markdown]
# ## Electrical Engineering Faculty Data

# %%
ee_file = pd.read_csv("ee.csv")
ee_new_data_frame = pd.DataFrame(ee_file)
ee_new_data_frame.head()
# Out:
#    Unnamed: 0    ID                Name          Designation  \
# 0           0  4198     Dr. Saima Zafar      Professor & HOD
# 1           1  4108      Dr. S.M. Sajid            Professor
# 2           2  5421  Dr. Syed Aun Abbas            Professor
# 3           3  4609     Dr. Omer Saleem  Associate Professor
# 4           4  6942    Dr. Huzaifa Rauf  Assistant Professor
#
#    HEC Approved PHD Supervisor                   Email Department  \
# 0                         True   saima.zafar@nu.edu.pk         ee
# 1                         True      sm.sajid@nu.edu.pk         ee
# 2                        False     aun.abbas@nu.edu.pk         ee
# 3                         True   omer.saleem@nu.edu.pk         ee
# 4                        False  huzaifa.rauf@nu.edu.pk         ee
#
#                                             ImageURL
# 0     /media/Faculty/98._Dr_Saima_Zafar_Prof._EE.JPG
# 1       /media/Faculty/99._Dr_S_M_Sajid_Prof._EE.JPG
# 2  /media/Faculty/100._Dr_Syed_Aun_Abbas_Prof._EE...
# 3  /media/Faculty/101._Dr_Omer_Saleem_Associate_P...
# 4  /media/Faculty/Dr._Huzaifa_Rauf-removebg-previ...

# %%
ID_List = ee_new_data_frame["ID"].tolist()
print(ID_List)

ID_data_frame = pd.DataFrame(columns=["ID", "Extension", "Highest Education"])
ID_data_frame.head()
# Out:
# [4198, 4108, 5421, 4609, 6942, 9452, 4023, 4233, 3669, 3461, 4484, 3778, 7025, 6289, 3779, 5218, 4809, 6843, 5231, 6557, 7005, 6665, 6830, 7002]
# Empty DataFrame
# Columns: [ID, Extension, Highest Education]
# Index: []

# %% [markdown]
# ## New data Frame

# %%
data_list = []

for ID in ID_List:
    URL = f"http://lhr.nu.edu.pk/ee/facultyProfile/{ID}"
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, "html.parser")

    # Extracting Extension
    extension = "N/A"
    phone_ext = soup.find("span", class_="small")
    if phone_ext and "Ext:" in phone_ext.text:
        extension = phone_ext.text.split("Ext:")[1].strip()

    # Extracting Education (highest degree)
    latest_education = "N/A"
    education_section = soup.find(
        "div", class_="col-lg-8 col-md-6 col-sm-12 text-justify"
    )
    if education_section:
        ul_tag = education_section.find("ul")
        if ul_tag:
            li_tags = ul_tag.find_all("li")
            if li_tags:
                latest_education = li_tags[0].text.strip()

    new_data = {"ID": ID, "Extension": extension, "Highest Education": latest_education}

    data_list.append(new_data)

# %%
ID_data_frame = pd.DataFrame(data_list)
ID_data_frame.head()
# Out:
#      ID Extension                                  Highest Education
# 0  4198       265   PhD (Electrical Engineering), UET, Lahore (2011)
# 1  4108       315  PhD (Electrical Engineering), Graz University ...
# 2  5421       254  PhD (Electrical Engineering),Carleton Universi...
# 3  4609       364   PhD (Electrical Engineering), UET, Lahore (2021)
# 4  6942       235                      PhD (EE), LUMS, Lahore (2024)

# %% [markdown]
# ## Import to .csv file

# %%
ID_data_frame.to_csv("ee_2.csv")

# %% [markdown]
# ## Civil Engineering Faculty Data

# %%
cv_file = pd.read_csv("cv.csv")
cv_new_data_frame = pd.DataFrame(cv_file)
cv_new_data_frame.head()
# Out:
#    Unnamed: 0    ID                         Name                Designation  \
# 0           0  5818             Dr. Tauqir Ahmed  Associate Professor & HOD
# 1           1  9451               Dr. Shahid Ali                  Professor
# 2           2  5705  Dr. Syed Ali Rizwan Bukhari                  Professor
# 3           3  6941            Dr. Muhammad Azam        Assistant Professor
# 4           4  6047            Dr. Muhammad Umar        Assistant Professor
#
#    HEC Approved PHD Supervisor                    Email Department  \
# 0                         True   tauqir.ahmed@nu.edu.pk         cv
# 1                         True     shahid.ali@nu.edu.pk         cv
# 2                         True       syed.ali@nu.edu.pk         cv
# 3                        False  muhammad.azam@nu.edu.pk         cv
# 4                         True         m.umar@nu.edu.pk         cv
#
#                                             ImageURL
# 0   /media/Faculty/77._Dr_Tauqir_Ahmed_Prof._CvL.jpg
# 1     /media/Faculty/78._Dr_Shahid_Ali_Prof._CvL.JPG
# 2  /media/Faculty/79._Dr_Syed_Ali_Rizwan_Prof._Cv...
# 3  /media/Faculty/Dr._Muhammad_Azam-removebg-prev...
# 4  /media/Faculty/80._Dr_Muhammad_Umar_Asst._Prof...

# %%
ID_List = cv_new_data_frame["ID"].tolist()
print(ID_List)

ID_data_frame = pd.DataFrame(columns=["ID", "Extension", "Highest Education"])
ID_data_frame.head()
# Out:
# [5818, 9451, 5705, 6941, 6047, 9513, 4592, 5360, 6041, 4300, 6839, 5553, 6573, 6817, 7026, 6818, 6816, 6569, 6934, 6769, 6571, 6933]
# Empty DataFrame
# Columns: [ID, Extension, Highest Education]
# Index: []

# %% [markdown]
# ## New data Frame

# %%
data_list = []

for ID in ID_List:
    URL = f"http://lhr.nu.edu.pk/cv/facultyProfile/{ID}"
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, "html.parser")

    # Extracting Extension
    extension = "N/A"
    phone_ext = soup.find("span", class_="small")
    if phone_ext and "Ext:" in phone_ext.text:
        extension = phone_ext.text.split("Ext:")[1].strip()

    # Extracting Education (highest degree)
    latest_education = "N/A"
    education_section = soup.find(
        "div", class_="col-lg-8 col-md-6 col-sm-12 text-justify"
    )
    if education_section:
        ul_tag = education_section.find("ul")
        if ul_tag:
            li_tags = ul_tag.find_all("li")
            if li_tags:
                latest_education = li_tags[0].text.strip()

    new_data = {"ID": ID, "Extension": extension, "Highest Education": latest_education}

    data_list.append(new_data)

# %%
ID_data_frame = pd.DataFrame(data_list)
ID_data_frame.head()
# Out:
#      ID Extension                                  Highest Education
# 0  5818       417  PhD (Civil Engineering), The University of Tok...
# 1  9451       339  PhD (Hydraulics), Delft University of Technolo...
# 2  5705       228  Post-Doctorate (High Early Strength Self-Compa...
# 3  6941       414  PhD (Civil Engineering), Universiti Teknologi,...
# 4  6047       450  PhD (Civil Engineering), University of Tokyo, ...

# %% [markdown]
# ## Import to .csv file

# %%
ID_data_frame.to_csv("cv_2.csv")

# %% [markdown]
# ## FAST School of Management Faculty Data

# %%
fsm_file = pd.read_csv("fsm.csv")
fsm_new_data_frame = pd.DataFrame(fsm_file)
fsm_new_data_frame.head()
# Out:
#    Unnamed: 0    ID                      Name                   Designation  \
# 0           0  3924          Dr. Hamid Hassan               Professor & HOD
# 1           1  4685            Dr. Akbar Azam           Associate Professor
# 2           2  6563          Dr. Amna Farrukh  Assistant Professor On Leave
# 3           3  5712  Dr. Brig Mujahid Hussain           Assistant Professor
# 4           4  4629           Dr. Fatima Omer           Assistant Professor
#
#    HEC Approved PHD Supervisor                      Email Department  \
# 0                         True     hamid.hassan@nu.edu.pk        fsm
# 1                         True       akbar.azam@nu.edu.pk        fsm
# 2                        False     amna.farrukh@nu.edu.pk        fsm
# 3                         True  mujahid.hussain@nu.edu.pk        fsm
# 4                        False      fatima.omer@nu.edu.pk        fsm
#
#                                             ImageURL
# 0    /media/Faculty/121._Dr_Hamid_Hassan_Prof_MG.JPG
# 1  /media/Faculty/122.Dr_Akbar_Azam_Assoc._Prof._...
# 2  /media/Faculty/126._Amna_Farrukh_Assit_Prof._M...
# 3  /media/Faculty/128._Dr_Mujahid_Hussain_Asst._P...
# 4  /media/Faculty/125._Dr_Fatima_Omer_Asst._Prof....

# %%
ID_List = fsm_new_data_frame["ID"].tolist()
print(ID_List)

ID_data_frame = pd.DataFrame(columns=["ID", "Extension", "Highest Education"])
ID_data_frame.head()
# Out:
# [3924, 4685, 6563, 5712, 4629, 6561, 5423, 5559, 5427, 6426, 9495, 4483, 4647, 5517, 5227, 6930, 5518, 6115, 6709, 6565, 6664, 6812, 6566, 5713, 6813, 6303, 6931, 7016, 7017, 6789, 7015, 6964, 6790, 6815, 6932]
# Empty DataFrame
# Columns: [ID, Extension, Highest Education]
# Index: []

# %% [markdown]
# ## New data Frame

# %%
data_list = []

for ID in ID_List:
    URL = f"http://lhr.nu.edu.pk/fsm/facultyProfile/{ID}"
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, "html.parser")

    # Extracting Extension
    extension = "N/A"
    phone_ext = soup.find("span", class_="small")
    if phone_ext and "Ext:" in phone_ext.text:
        extension = phone_ext.text.split("Ext:")[1].strip()

    # Extracting Education (highest degree)
    latest_education = "N/A"
    education_section = soup.find(
        "div", class_="col-lg-8 col-md-6 col-sm-12 text-justify"
    )
    if education_section:
        ul_tag = education_section.find("ul")
        if ul_tag:
            li_tags = ul_tag.find_all("li")
            if li_tags:
                latest_education = li_tags[0].text.strip()

    new_data = {"ID": ID, "Extension": extension, "Highest Education": latest_education}

    data_list.append(new_data)

# %%
ID_data_frame = pd.DataFrame(data_list)
ID_data_frame.head()
# Out:
#      ID Extension                                  Highest Education
# 0  3924       252  PhD (HRM/Finance), University of Tsukuba, Japa...
# 1  4685       343  PhD (General Management), University of Bologn...
# 2  6563       405  PhD (Engineering Management), Massey Universit...
# 3  5712       255     PhD (Management Science), NUCES, Lahore (2018)
# 4  4629       295  PhD (Management Science), NUCES, Lahore , Paki...

# %% [markdown]
# ## Import to .csv file

# %%
ID_data_frame.to_csv("fsm_2.csv")

# %% [markdown]
# ## Department of Science and Humanities Faculty Data

# %%
ss_file = pd.read_csv("ss.csv")
ss_new_data_frame = pd.DataFrame(ss_file)
ss_new_data_frame.head()
# Out:
#    Unnamed: 0    ID                     Name  \
# 0           0  4332      Dr. Mubashir Qayyum
# 1           1  4020  Dr. Akhlaq Ahmad Bhatti
# 2           2  3712       Dr. Mazhar Hussain
# 3           3  4250         Dr. Saman Shahid
# 4           4  4018     Dr. Summaira Sarfraz
#
#                                          Designation  \
# 0                                    Professor & HOD
# 1  Professor Dean (Faculty of Sciences & Humanities)
# 2                                          Professor
# 3                                          Professor
# 4                                          Professor
#
#    HEC Approved PHD Supervisor                      Email Department  \
# 0                         True  mubashir.qayyum@nu.edu.pk         ss
# 1                         True     akhlaq.ahmad@nu.edu.pk         ss
# 2                         True   mazhar.hussain@nu.edu.pk         ss
# 3                         True     saman.shahid@nu.edu.pk         ss
# 4                         True  sumaira.sarfraz@nu.edu.pk         ss
#
#                                             ImageURL
# 0  /media/Faculty/149._Dr_Mubashir_Qayyum_Prof._S...
# 1  /media/Faculty/150._Dr._Akhlaq_Ahmad_Bhatti_Pr...
# 2  /media/Faculty/151._Dr_Mazhar_Hussain_Prof._SH...
# 3  /media/Faculty/152._Dr._Saman_Shahid_Prof._SH.jpg
# 4  /media/Faculty/148._Dr_Summaira_Sarfraz_Prof._...

# %%
ID_List = ss_new_data_frame["ID"].tolist()
print(ID_List)

ID_data_frame = pd.DataFrame(columns=["ID", "Extension", "Highest Education"])
ID_data_frame.head()
# Out:
# [4332, 4020, 3712, 4250, 4018, 4584, 1250, 4608, 9172, 6768, 5437, 6926, 9173, 4243, 4244, 4245, 5438, 5622, 6555, 5203, 4397, 6421, 6365, 6178, 6420, 5795, 6548, 5337, 6363, 6567]
# Empty DataFrame
# Columns: [ID, Extension, Highest Education]
# Index: []

# %% [markdown]
# ## New data Frame

# %%
data_list = []

for ID in ID_List:
    URL = f"http://lhr.nu.edu.pk/ss/facultyProfile/{ID}"
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, "html.parser")

    # Extracting Extension
    extension = "N/A"
    phone_ext = soup.find("span", class_="small")
    if phone_ext and "Ext:" in phone_ext.text:
        extension = phone_ext.text.split("Ext:")[1].strip()

    # Extracting Education (highest degree)
    latest_education = "N/A"
    education_section = soup.find(
        "div", class_="col-lg-8 col-md-6 col-sm-12 text-justify"
    )
    if education_section:
        ul_tag = education_section.find("ul")
        if ul_tag:
            li_tags = ul_tag.find_all("li")
            if li_tags:
                latest_education = li_tags[0].text.strip()

    new_data = {"ID": ID, "Extension": extension, "Highest Education": latest_education}

    data_list.append(new_data)

# %%
ID_data_frame = pd.DataFrame(data_list)
ID_data_frame.head()
# Out:
#      ID Extension                                  Highest Education
# 0  4332       283  PhD (Applied Mathematics), NUCES, Peshawar (2018)
# 1  4020       284  PhD (Mathematics/ Hypergraph Theory), GCU Laho...
# 2  3712       313           PhD (Mathematics), QAU, Islamabad (2008)
# 3  4250       206     PhD (Environmental Science), PU, Lahore (2015)
# 4  4018       227    PhD (English), AJ&K University, Pakistan (2013)

# %% [markdown]
# ## Import to .csv file

# %%
ID_data_frame.to_csv("ss_2.csv")

# %% [markdown]
# # **Step#3 Data Integration**

# %% [markdown]
# ## FAST School of Computing

# %%
fsc_temp = pd.read_csv("fsc.csv")
fsc_2_temp = pd.read_csv("fsc_2.csv")

merged_df_fsc = pd.merge(fsc_temp, fsc_2_temp, on="ID", how="left")
merged_df_fsc = merged_df_fsc.drop(columns=["Unnamed: 0_x", "Unnamed: 0_y"])

merged_df_fsc.head()
# Out:
#      ID                      Name      Designation  \
# 0  1238          Dr. Kashif Zafar  Professor & HOD
# 1  4027            Dr. Aamir Wali        Professor
# 2  4391  Dr. Asif Mahmood Gillani        Professor
# 3  6113           Dr. Asma Naseer        Professor
# 4  4329        Dr. Zareen Alamgir        Professor
#
#    HEC Approved PHD Supervisor                     Email Department  \
# 0                         True    kashif.zafar@nu.edu.pk        fsc
# 1                         True      aamir.wali@nu.edu.pk        fsc
# 2                         True     asif.gilani@nu.edu.pk        fsc
# 3                         True     asma.naseer@nu.edu.pk        fsc
# 4                         True  zareen.alamgir@nu.edu.pk        fsc
#
#                                             ImageURL  Extension  \
# 0    /media/Faculty/01._Dr_Kashif_Zafar_Prof._CS.JPG      569.0
# 1    /media/Faculty/51._Dr_Aamir_Wali_Prof._AIDS.JPG      572.0
# 2  /media/Faculty/02._Dr_Asif_Mehmood_Gilani_Prof...      558.0
# 3  /media/Faculty/07._Dr_Asma_Naseer_Assoc._Prof....      634.0
# 4  /media/Faculty/03._Dr_Zareen_Alamgir_Prof._CS.JPG      612.0
#
#                                    Highest Education
# 0                  PhD (CS), NUCES, Islamabad (2010)
# 1                     PhD (CS), NUCES, Lahore (2019)
# 2  Ph.D(Computing), University of Patras , Greece...
# 3                     PhD (CS), NUCES, Lahore (2018)
# 4                    Ph.D (CS), NUCES, Lahore (2014)

# %% [markdown]
# ## Department of Electrical Engineering

# %%
ee_temp = pd.read_csv("ee.csv")
ee_2_temp = pd.read_csv("ee_2.csv")

merged_df_ee = pd.merge(ee_temp, ee_2_temp, on="ID", how="left")
merged_df_ee = merged_df_ee.drop(columns=["Unnamed: 0_x", "Unnamed: 0_y"])

merged_df_ee.head()
# Out:
#      ID                Name          Designation  HEC Approved PHD Supervisor  \
# 0  4198     Dr. Saima Zafar      Professor & HOD                         True
# 1  4108      Dr. S.M. Sajid            Professor                         True
# 2  5421  Dr. Syed Aun Abbas            Professor                        False
# 3  4609     Dr. Omer Saleem  Associate Professor                         True
# 4  6942    Dr. Huzaifa Rauf  Assistant Professor                        False
#
#                     Email Department  \
# 0   saima.zafar@nu.edu.pk         ee
# 1      sm.sajid@nu.edu.pk         ee
# 2     aun.abbas@nu.edu.pk         ee
# 3   omer.saleem@nu.edu.pk         ee
# 4  huzaifa.rauf@nu.edu.pk         ee
#
#                                             ImageURL  Extension  \
# 0     /media/Faculty/98._Dr_Saima_Zafar_Prof._EE.JPG      265.0
# 1       /media/Faculty/99._Dr_S_M_Sajid_Prof._EE.JPG      315.0
# 2  /media/Faculty/100._Dr_Syed_Aun_Abbas_Prof._EE...      254.0
# 3  /media/Faculty/101._Dr_Omer_Saleem_Associate_P...      364.0
# 4  /media/Faculty/Dr._Huzaifa_Rauf-removebg-previ...      235.0
#
#                                    Highest Education
# 0   PhD (Electrical Engineering), UET, Lahore (2011)
# 1  PhD (Electrical Engineering), Graz University ...
# 2  PhD (Electrical Engineering),Carleton Universi...
# 3   PhD (Electrical Engineering), UET, Lahore (2021)
# 4                      PhD (EE), LUMS, Lahore (2024)

# %% [markdown]
# ## Department of Civil Engineering

# %%
cv_temp = pd.read_csv("cv.csv")
cv_2_temp = pd.read_csv("cv_2.csv")

merged_df_cv = pd.merge(cv_temp, cv_2_temp, on="ID", how="left")
merged_df_cv = merged_df_cv.drop(columns=["Unnamed: 0_x", "Unnamed: 0_y"])

merged_df_cv.head()
# Out:
#      ID                         Name                Designation  \
# 0  5818             Dr. Tauqir Ahmed  Associate Professor & HOD
# 1  9451               Dr. Shahid Ali                  Professor
# 2  5705  Dr. Syed Ali Rizwan Bukhari                  Professor
# 3  6941            Dr. Muhammad Azam        Assistant Professor
# 4  6047            Dr. Muhammad Umar        Assistant Professor
#
#    HEC Approved PHD Supervisor                    Email Department  \
# 0                         True   tauqir.ahmed@nu.edu.pk         cv
# 1                         True     shahid.ali@nu.edu.pk         cv
# 2                         True       syed.ali@nu.edu.pk         cv
# 3                        False  muhammad.azam@nu.edu.pk         cv
# 4                         True         m.umar@nu.edu.pk         cv
#
#                                             ImageURL  Extension  \
# 0   /media/Faculty/77._Dr_Tauqir_Ahmed_Prof._CvL.jpg      417.0
# 1     /media/Faculty/78._Dr_Shahid_Ali_Prof._CvL.JPG      339.0
# 2  /media/Faculty/79._Dr_Syed_Ali_Rizwan_Prof._Cv...      228.0
# 3  /media/Faculty/Dr._Muhammad_Azam-removebg-prev...      414.0
# 4  /media/Faculty/80._Dr_Muhammad_Umar_Asst._Prof...      450.0
#
#                                    Highest Education
# 0  PhD (Civil Engineering), The University of Tok...
# 1  PhD (Hydraulics), Delft University of Technolo...
# 2  Post-Doctorate (High Early Strength Self-Compa...
# 3  PhD (Civil Engineering), Universiti Teknologi,...
# 4  PhD (Civil Engineering), University of Tokyo, ...

# %% [markdown]
# ## FAST School of Management

# %%
fsm_temp = pd.read_csv("fsm.csv")
fsm_2_temp = pd.read_csv("fsm_2.csv")

merged_df_fsm = pd.merge(fsm_temp, fsm_2_temp, on="ID", how="left")
merged_df_fsm = merged_df_fsm.drop(columns=["Unnamed: 0_x", "Unnamed: 0_y"])

merged_df_fsm.head()
# Out:
#      ID                      Name                   Designation  \
# 0  3924          Dr. Hamid Hassan               Professor & HOD
# 1  4685            Dr. Akbar Azam           Associate Professor
# 2  6563          Dr. Amna Farrukh  Assistant Professor On Leave
# 3  5712  Dr. Brig Mujahid Hussain           Assistant Professor
# 4  4629           Dr. Fatima Omer           Assistant Professor
#
#    HEC Approved PHD Supervisor                      Email Department  \
# 0                         True     hamid.hassan@nu.edu.pk        fsm
# 1                         True       akbar.azam@nu.edu.pk        fsm
# 2                        False     amna.farrukh@nu.edu.pk        fsm
# 3                         True  mujahid.hussain@nu.edu.pk        fsm
# 4                        False      fatima.omer@nu.edu.pk        fsm
#
#                                             ImageURL  Extension  \
# 0    /media/Faculty/121._Dr_Hamid_Hassan_Prof_MG.JPG      252.0
# 1  /media/Faculty/122.Dr_Akbar_Azam_Assoc._Prof._...      343.0
# 2  /media/Faculty/126._Amna_Farrukh_Assit_Prof._M...      405.0
# 3  /media/Faculty/128._Dr_Mujahid_Hussain_Asst._P...      255.0
# 4  /media/Faculty/125._Dr_Fatima_Omer_Asst._Prof....      295.0
#
#                                    Highest Education
# 0  PhD (HRM/Finance), University of Tsukuba, Japa...
# 1  PhD (General Management), University of Bologn...
# 2  PhD (Engineering Management), Massey Universit...
# 3     PhD (Management Science), NUCES, Lahore (2018)
# 4  PhD (Management Science), NUCES, Lahore , Paki...

# %% [markdown]
# ## Department of Science and Humanities

# %%
ss_temp = pd.read_csv("ss.csv")
ss_2_temp = pd.read_csv("ss_2.csv")

merged_df_ss = pd.merge(ss_temp, ss_2_temp, on="ID", how="left")
merged_df_ss = merged_df_ss.drop(columns=["Unnamed: 0_x", "Unnamed: 0_y"])

merged_df_ss.head()
# Out:
#      ID                     Name  \
# 0  4332      Dr. Mubashir Qayyum
# 1  4020  Dr. Akhlaq Ahmad Bhatti
# 2  3712       Dr. Mazhar Hussain
# 3  4250         Dr. Saman Shahid
# 4  4018     Dr. Summaira Sarfraz
#
#                                          Designation  \
# 0                                    Professor & HOD
# 1  Professor Dean (Faculty of Sciences & Humanities)
# 2                                          Professor
# 3                                          Professor
# 4                                          Professor
#
#    HEC Approved PHD Supervisor                      Email Department  \
# 0                         True  mubashir.qayyum@nu.edu.pk         ss
# 1                         True     akhlaq.ahmad@nu.edu.pk         ss
# 2                         True   mazhar.hussain@nu.edu.pk         ss
# 3                         True     saman.shahid@nu.edu.pk         ss
# 4                         True  sumaira.sarfraz@nu.edu.pk         ss
#
#                                             ImageURL  Extension  \
# 0  /media/Faculty/149._Dr_Mubashir_Qayyum_Prof._S...      283.0
# 1  /media/Faculty/150._Dr._Akhlaq_Ahmad_Bhatti_Pr...      284.0
# 2  /media/Faculty/151._Dr_Mazhar_Hussain_Prof._SH...      313.0
# 3  /media/Faculty/152._Dr._Saman_Shahid_Prof._SH.jpg      206.0
# 4  /media/Faculty/148._Dr_Summaira_Sarfraz_Prof._...      227.0
#
#                                    Highest Education
# 0  PhD (Applied Mathematics), NUCES, Peshawar (2018)
# 1  PhD (Mathematics/ Hypergraph Theory), GCU Laho...
# 2           PhD (Mathematics), QAU, Islamabad (2008)
# 3     PhD (Environmental Science), PU, Lahore (2015)
# 4    PhD (English), AJ&K University, Pakistan (2013)

# %% [markdown]
# ## Final Data File

# %%
# Concatenation of all the merged DataFrames
final_df = pd.concat(
    [merged_df_fsc, merged_df_ee, merged_df_cv, merged_df_fsm, merged_df_ss],
    ignore_index=True,
)
final_df.to_csv("fast_lhr_faculty.csv", index=False)

final_df.head()
# Out:
#      ID                      Name      Designation  \
# 0  1238          Dr. Kashif Zafar  Professor & HOD
# 1  4027            Dr. Aamir Wali        Professor
# 2  4391  Dr. Asif Mahmood Gillani        Professor
# 3  6113           Dr. Asma Naseer        Professor
# 4  4329        Dr. Zareen Alamgir        Professor
#
#    HEC Approved PHD Supervisor                     Email Department  \
# 0                         True    kashif.zafar@nu.edu.pk        fsc
# 1                         True      aamir.wali@nu.edu.pk        fsc
# 2                         True     asif.gilani@nu.edu.pk        fsc
# 3                         True     asma.naseer@nu.edu.pk        fsc
# 4                         True  zareen.alamgir@nu.edu.pk        fsc
#
#                                             ImageURL  Extension  \
# 0    /media/Faculty/01._Dr_Kashif_Zafar_Prof._CS.JPG      569.0
# 1    /media/Faculty/51._Dr_Aamir_Wali_Prof._AIDS.JPG      572.0
# 2  /media/Faculty/02._Dr_Asif_Mehmood_Gilani_Prof...      558.0
# 3  /media/Faculty/07._Dr_Asma_Naseer_Assoc._Prof....      634.0
# 4  /media/Faculty/03._Dr_Zareen_Alamgir_Prof._CS.JPG      612.0
#
#                                    Highest Education
# 0                  PhD (CS), NUCES, Islamabad (2010)
# 1                     PhD (CS), NUCES, Lahore (2019)
# 2  Ph.D(Computing), University of Patras , Greece...
# 3                     PhD (CS), NUCES, Lahore (2018)
# 4                    Ph.D (CS), NUCES, Lahore (2014)
